# %%
import dask.dataframe as dd

# %%
# The task herein is to make a function that extracts rows with a call to local storag APIs

# %%
#When a site is visited for the first time, cookies are installed for subsequent visits. 
#A Web site might generate a unique ID number for each visitor and store the number on the machine of each user
#using a cookie file. Since these files are stored in the local storage of the machine, we want to know which sites
#made calls to localstorage hence the function below. 
# To start with I made a list of localstorage spaces likely to be employed for such purposes.

# %%
# A list of localstorage spaces

stores = ['window.localStorage','window.document.cookie', 'window.sessionStorage']

# %%
# We start by defining a function we called 'findID'. Then we read the parquet file into a variable
#Second line involves filtering the calls made to ensure we get those within the list of localstorage spaces
# Last line is to make the table of results obtained. 

def findID(dataset):
    ddf = dd.read_parquet(dataset, engine='pyarrow') 
    unique_symbl = ddf.symbol.isin(stores) 
    new_table = ddf[unique_symbl] 
    return new_table

# I actually used the 10 percent data size to test the function as seen below. 
#findID('./sample_10percent_value_1000_only.parquet').head()
# Out:
#    argument_0 argument_1 argument_2 argument_3 argument_4 argument_5  \
# 4        None       None       None       None       None       None
# 7        None       None       None       None       None       None
# 8        None       None       None       None       None       None
# 9        None       None       None       None       None       None
# 10       None       None       None       None       None       None
#
#    argument_6 argument_7 argument_8 arguments    ...      \
# 4        None       None       None        {}    ...
# 7        None       None       None       nan    ...
# 8        None       None       None       nan    ...
# 9        None       None       None       nan    ...
# 10       None       None       None       nan    ...
#
#                                              location operation  script_col  \
# 4   http://serienjunkies.org/smilf/smilf-season-1-...       get          32
# 7              https://www.canada.ca/en/services.html       set        3048
# 8              https://www.canada.ca/en/services.html       get        2519
# 9              https://www.canada.ca/en/services.html       get         191
# 10             https://www.canada.ca/en/services.html       get         191
#
#    script_line script_loc_eval  \
# 4           59
# 7            8
# 8            8
# 9           27
# 10          27
#
#                                            script_url                  symbol  \
# 4   https://apis.google.com/js/plusone.js?_=151338...  window.document.cookie
# 7   https://assets.adobedtm.com/caacec67651710193d...  window.document.cookie
# 8   https://assets.adobedtm.com/caacec67651710193d...  window.document.cookie
# 9   https://assets.adobedtm.com/caacec67651710193d...  window.document.cookie
# 10  https://assets.adobedtm.com/caacec67651710193d...  window.document.cookie
#
#                 time_stamp                                         value_1000  \
# 4  2017-12-16 01:24:30.372  _ga=GA1.2.1529583939.1513387469; _gid=GA1.2.17...
# 7  2017-12-16 02:54:21.633  AMCV_A90F2A0D55423F537F000101%40AdobeOrg=10994...
# 8  2017-12-16 02:54:21.634  AMCV_A90F2A0D55423F537F000101%40AdobeOrg=10994...
# 9  2017-12-16 02:54:21.638  AMCV_A90F2A0D55423F537F000101%40AdobeOrg=10994...
# 10 2017-12-16 02:54:21.639  AMCV_A90F2A0D55423F537F000101%40AdobeOrg=10994...
#
#     value_len
# 4         288
# 7         347
# 8         326
# 9         326
# 10        326
#
# [5 rows x 26 columns]

# %%
#If the function above is approved, I think the next step is to check for the string 'id/ID/userID' or something.
