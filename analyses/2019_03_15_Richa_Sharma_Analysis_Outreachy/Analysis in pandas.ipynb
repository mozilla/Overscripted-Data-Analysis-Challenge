# %%
import tldextract

DATA_DIR = '/home/alvis/Desktop/Richa/overscripted/'
PARQUET_FILE = DATA_DIR + 'sample'  # I ran this with sample data*

def extract_domain(url):
    """Use tldextract to return the base domain from a url"""
    try:
        extracted = tldextract.extract(url)
        return '{}.{}'.format(extracted.domain, extracted.suffix)
    except Exception as e:
        return 'ERROR'

# %%
import pandas as pd

# %%
## Don't limit pandas display.
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", -1)

# %%
df = pd.read_parquet(PARQUET_FILE, engine='pyarrow')
df.head()
# Out:
#   argument_0 argument_1 argument_2 argument_3 argument_4 argument_5  \
# 0
# 1
# 2
# 3
# 4
#
#   argument_6 argument_7 argument_8 arguments  ...  script_line  \
# 0                                         {}  ...           57
# 1                                         {}  ...           57
# 2                                         {}  ...           57
# 3                                         {}  ...           49
# 4                                         {}  ...           25
#
#   script_loc_eval                                         script_url  \
# 0                  https://staticxx.facebook.com/connect/xd_arbit...
# 1                  https://staticxx.facebook.com/connect/xd_arbit...
# 2                  https://staticxx.facebook.com/connect/xd_arbit...
# 3                  https://staticxx.facebook.com/connect/xd_arbit...
# 4                  https://ajax.googleapis.com/ajax/libs/webfont/...
#
#                        symbol              time_stamp  \
# 0                 window.name 2017-12-16 02:54:10.079
# 1                 window.name 2017-12-16 02:54:10.080
# 2      window.document.cookie 2017-12-16 02:54:10.086
# 3  window.navigator.userAgent 2017-12-16 02:54:10.088
# 4  window.navigator.userAgent 2017-12-16 07:12:07.104
#
#                                                value  \
# 0                                 fb_xdm_frame_https
# 1                                 fb_xdm_frame_https
# 2
# 3  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...
# 4  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...
#
#                                           value_1000 value_len valid errors
# 0                                 fb_xdm_frame_https        18  True
# 1                                 fb_xdm_frame_https        18  True
# 2                                                            0  True
# 3  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...        68  True
# 4  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko...        68  True
#
# [5 rows x 30 columns]

# %%
df.iloc[35:38]
# Out:
#    argument_0 argument_1 argument_2 argument_3 argument_4 argument_5  \
# 35
# 36
# 37
#
#    argument_6 argument_7 argument_8 arguments  arguments_n_keys  \
# 35                                   {}        0
# 36                                   {}        0
# 37                                   {}        0
#
#                                                                 call_id  \
# 35  1_071cdfb020f03777dee481dca0ce4ea47e337107427d4005e2738a29.json__22
# 36  1_071cdfb020f03777dee481dca0ce4ea47e337107427d4005e2738a29.json__23
# 37  1_071cdfb020f03777dee481dca0ce4ea47e337107427d4005e2738a29.json__24
#
#    call_stack  crawl_id  \
# 35             1
# 36             1
# 37             1
#
#                                                           file_name func_name  \
# 35  1_071cdfb020f03777dee481dca0ce4ea47e337107427d4005e2738a29.json
# 36  1_071cdfb020f03777dee481dca0ce4ea47e337107427d4005e2738a29.json  c
# 37  1_071cdfb020f03777dee481dca0ce4ea47e337107427d4005e2738a29.json  Kc
#
#     in_iframe                         location operation script_col  \
# 35  False      https://www.syracuse.edu/about/  get       1402
# 36  False      https://www.syracuse.edu/about/  get       2650
# 37  False      https://www.syracuse.edu/about/  get       144
#
#    script_line script_loc_eval  \
# 35  95
# 36  4
# 37  45
#
#                                                                    script_url  \
# 35  https://www.googletagmanager.com/gtm.js?id=GTM-5FC97GL
# 36  https://www.syracuse.edu/wp-includes/js/wp-emoji-release.min.js?ver=4.9.1
# 37  https://www.google-analytics.com/analytics.js
#
#                         symbol              time_stamp  \
# 35  window.navigator.userAgent 2017-12-16 01:27:46.738
# 36  window.navigator.userAgent 2017-12-16 01:27:47.129
# 37  window.screen.colorDepth   2017-12-16 01:27:47.143
#
#                                                                    value  \
# 35  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
# 36  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
# 37  24
#
#                                                               value_1000  \
# 35  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
# 36  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
# 37  24
#
#     value_len  valid errors
# 35  68         True
# 36  68         True
# 37  2          True

# %%
fing = df[df.argument_0.str.contains('Cwm fjordbank glyphs vext quiz')]
fing.head()
# Out:
# Empty DataFrame
# Columns: [argument_0, argument_1, argument_2, argument_3, argument_4, argument_5, argument_6, argument_7, argument_8, arguments, arguments_n_keys, call_id, call_stack, crawl_id, file_name, func_name, in_iframe, location, operation, script_col, script_line, script_loc_eval, script_url, symbol, time_stamp, value, value_1000, value_len, valid, errors]
# Index: []

# %%
akam_f = df[df.script_url.str.contains('/akam/')]
akam_f.head()
