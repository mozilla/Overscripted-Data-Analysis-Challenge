# %% [markdown]
# ## Browser Attribute Fingerprinting.
#
# Browser Attribute Fingerprinting referes to uniquely identifing a client based on a set of browser attributes. This kind of fingerprinting is difficult to evade because it doesn't store any cookies on the client-end. Secondly innocuous choices like enabling or disabling a plugin or an add-on adds to a unique identity of a client. Something like adding the system to a no-tracker list in itself adds a unique attribute about the client to the list and in turn increases the chances of a successful fingerprinting.
#
# Browser Fingerprinting can loosely be defined (but not restricted to) as collecting following information: Browser Plugins, Browser Add-on Enumeration, System Fonts Enumeration, User Agent String, Screen Resolution etc. Details about these can be found [here](https://multilogin.com/browser-fingerprinting-the-surveillance-you-can-t-stop/)
#
# The questions I am trying to answer in this analysis:
#
# - __Detect all the scripts linked in the dataset which can be used for browser finger printing.__ As discussed in [#34](https://github.com/mozilla/overscripted/issues/34) we already know that `hs-analytics`, `fingerprint2.js` and `/akam/` are scripts used for fingerprinting. Can we find features in the dataset using which we can identify other such scripts?
#
# - __Understand which script uses what information to do the fingerprinting.__ This is useful to develop a broad heuristic which we can then employ to understand how prevalent is browser attribute fingerprinting in our dataset. Here I want to identify scripts which use plugin information vs scripts which employ add-ons or screen resolution details to fingerprint browsers. Idea here is that even if a script only takes plugin information it can potentially do fingerprinting without asking client for other attributes. Therefore we can not be too restrictive in our analysis/filtering.
#
# - __Develop a heuristic to identify cases of Browser Attribute Fingerprinting.__ Finally I want to come up with a rule based heuristic which is smart enough to catch all cases of browser attribute fingerprinting. This is linked to both Q1 and Q2. Answering this would require a reasonable progress on both of the earlier questions.
#
# *Note: Present work is towards my application to Outreachy program. I have restricted the analysis to 1 parquet file and all of this can be extended to the whole dataset with dask/spark. In interest of time and to focus more on analysis I have shown results only with pandas*

# %% [markdown]
# ## Getting Started
# Basic import statements for different libraries used below and corresponding display settings

# %%
import numpy as np
import pandas as pd
import tldextract
from urllib.parse import urlparse
import os

# %%
## Don't limit pandas display.
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", -1)

# %% [markdown]
# ## Helper functions
# Some useful functions defined here which can be used in analysis

# %%
def extract_domain(url):
    """Use tldextract to return the base domain from a url"""
    try:
        extracted = tldextract.extract(url)
        return '{}.{}'.format(extracted.domain, extracted.suffix)
    except Exception as e:
        return 'ERROR'

# %%
#Borrowed from 2018_09_biskit1_mordax__canvas_fingerprinting notebook
def parse_base_url(url):
  return urlparse(url).netloc # Extract the base part of a URL (netloc, up until the first '/').

# %%
def write_csv(path,name,df):
    df.to_csv(os.path.join(path,name))

# %%
def print_groupby(grouped_df):
    for key, item in grouped_df:
        print(grouped_df.get_group(key), "\n\n")

# %%
def get_end_of_path(x):
    splits = x.split('/')
    val = ''
    if len(splits) > 0:
        val = splits[-1]
    else:
        val = x
    if len(val) == 0:
        val = EMPTY_STRING
    return val

# %% [markdown]
# ## Data directory
# Change below to point to data location

# %%
DATA_DIR = '/home/alvis/Desktop/Richa/overscripted/sample.parquet/'
DATA_DIR = '/home/alvis/Desktop/Richa/overscripted/sample/'
PARQUET_FILE = DATA_DIR + 'part.0.parquet'
PARQUET_FILE = DATA_DIR + 'sample1.parquet'# I ran this with sample data*
IMP_COLUMNS = ['arguments','in_iframe', 'location', 'operation', 'script_url','symbol','time_stamp','value_1000','location_domain','script_domain','location_base_url']

# %%
df = pd.read_parquet(PARQUET_FILE, engine='pyarrow')
df.head()
# Out:
#   argument_0 argument_1 argument_2 argument_3 argument_4 argument_5  \
# 0
# 1
# 2
# 3
# 4
#
#   argument_6 argument_7 argument_8 arguments  arguments_n_keys  \
# 0                                   {}        0
# 1                                   {}        0
# 2                                   {}        0
# 3                                   {}        0
# 4                                   {}        0
#
#                                                               call_id  \
# 0  1_028048bbce3f7816a5f1277ac3ac2372d6607581a77a4bfb7a1873ab.json__0
# 1  1_028048bbce3f7816a5f1277ac3ac2372d6607581a77a4bfb7a1873ab.json__1
# 2  1_028048bbce3f7816a5f1277ac3ac2372d6607581a77a4bfb7a1873ab.json__2
# 3  1_028048bbce3f7816a5f1277ac3ac2372d6607581a77a4bfb7a1873ab.json__3
# 4  1_0401c74e1e381c6f4ebd5ca99102f1529c9a843360d6c9211525136f.json__0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               call_stack  \
# 0
# 1
# 2  A@https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com:57:2781\nx@https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com:55:3028\nw@https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com:55:931\na/<@https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com:57:2353\na@https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com:57:114\nrequire@https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com:36:610\n@https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com:57:3019
# 3
# 4
#
#    crawl_id                                                        file_name  \
# 0  1         1_028048bbce3f7816a5f1277ac3ac2372d6607581a77a4bfb7a1873ab.json
# 1  1         1_028048bbce3f7816a5f1277ac3ac2372d6607581a77a4bfb7a1873ab.json
# 2  1         1_028048bbce3f7816a5f1277ac3ac2372d6607581a77a4bfb7a1873ab.json
# 3  1         1_028048bbce3f7816a5f1277ac3ac2372d6607581a77a4bfb7a1873ab.json
# 4  1         1_0401c74e1e381c6f4ebd5ca99102f1529c9a843360d6c9211525136f.json
#
#   func_name  in_iframe  \
# 0  a/<       True
# 1  a/<       True
# 2  A         True
# 3  x         True
# 4  ra/<      True
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              location  \
# 0  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 1  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 2  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 3  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 4  https://cas.us.criteo.com/delivery/r/afr.php?did=5a34c73ff17390f0eaeb591979874b00&z=WjTHPwAHZYkKT7BIAAcskrRh4Qozh3b-c-mtZg&u=%7C7J5NcLNwKWZvhHazrdQ0r3pEybQM2VrhNSue519M%2FnU%3D%7C&c1=M5BADJe1UR3zJ2HNju9b10FggySKKMK0AoYTtPDcqDnSIQIZUQPlDupK--OP2eR-eNGQ46cgN3mwCl5UMg4IstlvomsUbHEHUzImPBAbL0KpTFeMsdEkBo28MAQVY_79HvMen3pU9pjoRxbnxk_AxatU3fdvCPtFY7Wzui5q962zi71J5i_HHNmYi7XbHxLl1v3NLOEqWiI-3QfHE1byzwOhuyge44QAJfUpukDSr4X723xUoquihjIy6b6D_yU9AsLHIIxKQk64_ES4G8moUw5dbt7SG3KWRhyjzAZW5acfRwaX8v33UzaCSZKj4O0XffzJaDiMmsprtAOP0J4xHPtfZqvurKt_x3z5y83mK1o&ct0=https://adclick.g.doubleclick.net/aclk%3Fsa%3Dl%26ai%3DCcqaRP8c0WonLHcjgvgKS2ZyADO7lmPBNsu23nZ0BwI23ARABIABgyQaCARdjYS1wdWItNTc4NzU5MjQ4Mzc2Njc2MKABrN3-6APIAQngAgCoAwGqBMUBT9DGnU9Xf5zpWjsp7PXxVDLu7mhvsOzx8jjeTb-wk_FUQNpBqVd4QxwydKBkX31VemFtAuP1QMeGjoHagpA44JfU11OU46ZLmBKcADPeCDg8kDPJvowA7EbbZ6gvml2aRO7nKo1LHNbLoGTBvP6gmhnbhVqThagbrECDM6qxbcRiiWobTKajDG8KeWma5flmrMZiQe5Lu3cyX_WMmu36IIP2lojiMZaZvgiE_ncYb24UZCKxrORb0gO54t1XHQFwzDnBRPXgBAGABufvkeKYhIzL9gGgBiGoB6a-G9gHANIIBQiAYRAB8ggbYWR4LXN1YnN5bi0wOTI1MDI4NTk2NjIxNjE3%26num%3D1%26sig%3DAOD64_1ibrZmc1pVLttz4doqoDmSHOvwXg%26client%3Dca-pub-5787592483766760%26adurl%3D
#
#   operation script_col script_line script_loc_eval  \
# 0  get       1802       57
# 1  get       2895       57
# 2  get       2781       57
# 3  get       156        49
# 4  get       306        25
#
#                                                                                                                                   script_url  \
# 0  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 1  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 2  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 3  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 4  https://ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js
#
#                        symbol              time_stamp  \
# 0  window.name                2017-12-16 02:54:10.079
# 1  window.name                2017-12-16 02:54:10.080
# 2  window.document.cookie     2017-12-16 02:54:10.086
# 3  window.navigator.userAgent 2017-12-16 02:54:10.088
# 4  window.navigator.userAgent 2017-12-16 07:12:07.104
#
#                                                                   value  \
# 0  fb_xdm_frame_https
# 1  fb_xdm_frame_https
# 2
# 3  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
# 4  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
#
#                                                              value_1000  \
# 0  fb_xdm_frame_https
# 1  fb_xdm_frame_https
# 2
# 3  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
# 4  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
#
#    value_len  valid errors
# 0  18         True
# 1  18         True
# 2  0          True
# 3  68         True
# 4  68         True

# %%
len(df)
# Out:
# 9234

# %%
# Some location and script url cleansing. Nice idea from 2018_09_biskit1_mordax__canvas_fingerprinting
df['location_domain'] = df.location.apply(extract_domain)
df['script_domain'] = df.script_url.apply(extract_domain)
df['location_base_url'] = df.location.apply(parse_base_url)
#Reduced dataframe = Rdf
Rdf = df[IMP_COLUMNS]
Rdf.head()
# Out:
#   arguments  in_iframe  \
# 0  {}        True
# 1  {}        True
# 2  {}        True
# 3  {}        True
# 4  {}        True
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              location  \
# 0  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 1  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 2  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 3  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 4  https://cas.us.criteo.com/delivery/r/afr.php?did=5a34c73ff17390f0eaeb591979874b00&z=WjTHPwAHZYkKT7BIAAcskrRh4Qozh3b-c-mtZg&u=%7C7J5NcLNwKWZvhHazrdQ0r3pEybQM2VrhNSue519M%2FnU%3D%7C&c1=M5BADJe1UR3zJ2HNju9b10FggySKKMK0AoYTtPDcqDnSIQIZUQPlDupK--OP2eR-eNGQ46cgN3mwCl5UMg4IstlvomsUbHEHUzImPBAbL0KpTFeMsdEkBo28MAQVY_79HvMen3pU9pjoRxbnxk_AxatU3fdvCPtFY7Wzui5q962zi71J5i_HHNmYi7XbHxLl1v3NLOEqWiI-3QfHE1byzwOhuyge44QAJfUpukDSr4X723xUoquihjIy6b6D_yU9AsLHIIxKQk64_ES4G8moUw5dbt7SG3KWRhyjzAZW5acfRwaX8v33UzaCSZKj4O0XffzJaDiMmsprtAOP0J4xHPtfZqvurKt_x3z5y83mK1o&ct0=https://adclick.g.doubleclick.net/aclk%3Fsa%3Dl%26ai%3DCcqaRP8c0WonLHcjgvgKS2ZyADO7lmPBNsu23nZ0BwI23ARABIABgyQaCARdjYS1wdWItNTc4NzU5MjQ4Mzc2Njc2MKABrN3-6APIAQngAgCoAwGqBMUBT9DGnU9Xf5zpWjsp7PXxVDLu7mhvsOzx8jjeTb-wk_FUQNpBqVd4QxwydKBkX31VemFtAuP1QMeGjoHagpA44JfU11OU46ZLmBKcADPeCDg8kDPJvowA7EbbZ6gvml2aRO7nKo1LHNbLoGTBvP6gmhnbhVqThagbrECDM6qxbcRiiWobTKajDG8KeWma5flmrMZiQe5Lu3cyX_WMmu36IIP2lojiMZaZvgiE_ncYb24UZCKxrORb0gO54t1XHQFwzDnBRPXgBAGABufvkeKYhIzL9gGgBiGoB6a-G9gHANIIBQiAYRAB8ggbYWR4LXN1YnN5bi0wOTI1MDI4NTk2NjIxNjE3%26num%3D1%26sig%3DAOD64_1ibrZmc1pVLttz4doqoDmSHOvwXg%26client%3Dca-pub-5787592483766760%26adurl%3D
#
#   operation  \
# 0  get
# 1  get
# 2  get
# 3  get
# 4  get
#
#                                                                                                                                   script_url  \
# 0  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 1  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 2  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 3  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 4  https://ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js
#
#                        symbol              time_stamp  \
# 0  window.name                2017-12-16 02:54:10.079
# 1  window.name                2017-12-16 02:54:10.080
# 2  window.document.cookie     2017-12-16 02:54:10.086
# 3  window.navigator.userAgent 2017-12-16 02:54:10.088
# 4  window.navigator.userAgent 2017-12-16 07:12:07.104
#
#                                                              value_1000  \
# 0  fb_xdm_frame_https
# 1  fb_xdm_frame_https
# 2
# 3  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
# 4  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
#
#   location_domain   script_domain      location_base_url
# 0  facebook.com    facebook.com    staticxx.facebook.com
# 1  facebook.com    facebook.com    staticxx.facebook.com
# 2  facebook.com    facebook.com    staticxx.facebook.com
# 3  facebook.com    facebook.com    staticxx.facebook.com
# 4  criteo.com      googleapis.com  cas.us.criteo.com

# %% [markdown]
# Now that I have the dataframe in a more manageable form, I am looking for scripts/instances where information about Browser plugins is sought. `navigator.plugins[SOME PLUGIN]` is used to validate if a given plugin is enabled on a browser or not. [This](http://www.howtocreate.co.uk/wrongWithIE/?chapter=navigator.plugins) tells me that `navigator.mimeTypes` is a similar function. If navigator.plugin and navigator.mimeTypes are called together multiple times with different arguments they can be used for fingerprinting.

# %%
df_plugins = Rdf[Rdf.symbol.str.contains('navigator.mimeTypes|navigator.plugins')]
#write_csv(DATA_DIR,'df_plugins.csv',df_plugins)
#Locally write CSV, sometimes it is easier to slice and dice the data in excel. :)

# %% [markdown]
# ## Dataframe with rows which queried plugin information
# Let us see what these scripts are and what are the domains where they are hosted

# %%
Scripts_Calling_Plugins = df_plugins.script_url.unique()
Scripts_Calling_Plugins

# %%
# Lets see which script is being used the most
df_plugins['script_url'].value_counts()
# Out:
# https://mc.yandex.ru/metrika/watch.js                                                                                                                                                                                                                                                                                                  70
# https://www.google-analytics.com/analytics.js                                                                                                                                                                                                                                                                                          62
# https://securepubads.g.doubleclick.net/gpt/pubads_impl_170.js                                                                                                                                                                                                                                                                          58
# http://static.chartbeat.com/js/chartbeat_video.js                                                                                                                                                                                                                                                                                      24
# http://media.ufc.tv/ufc_system_assets/ufc_201707101050/js/jwplayer7/jwplayer.js                                                                                                                                                                                                                                                        20
# http://www.gap.com/akam/10/6e136b78                                                                                                                                                                                                                                                                                                    18
# http://static.chartbeat.com/js/chartbeat.js                                                                                                                                                                                                                                                                                            16
# https://securepubads.g.doubleclick.net/gpt/pubads_impl_moa_e_20171107.js                                                                                                                                                                                                                                                               12
# https://tpc.googlesyndication.com/sodar/Yww8ZxGu.js                                                                                                                                                                                                                                                                                    12
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                                                                                                                                                                                                                                                                      9
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js                                                                                                                                                                                                                                                   9
# https://www.pwc.com/etc/clientlibs/pwc/components-colors.min.js                                                                                                                                                                                                                                                                        8
# https://s3-ap-southeast-1.amazonaws.com/flipa-production/urdmp/universal.js                                                                                                                                                                                                                                                            6
# https://bat.bing.com/bat.js                                                                                                                                                                                                                                                                                                            6
# http://www.google-analytics.com/analytics.js                                                                                                                                                                                                                                                                                           6
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                                                                                                                                                                                                                                                                  5
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1                                                                                                                                                                                                                                                               5
# https://list.tmall.com/search_product.htm?abbucket=&pic_detail=1&active=1&acm=lb-zebra-22355-807833.1003.4.764609&sort=s&industryCatId=50106419&spm=a220m.1000858.1000721.5.8puO4R&abtest=&pos=13&cat=52588013&from=sn_1_cat&style=g&search_condition=55&scm=1003.4.lb-zebra-22355-807833.OTHER_147327151378711_764609&aldid=226900    4
# https://www.youtube.com/yts/jsbin/player-vflyoGrhd/en_US/base.js                                                                                                                                                                                                                                                                       4
# https://ssl.google-analytics.com/ga.js                                                                                                                                                                                                                                                                                                 4
# https://z.moatads.com/quantcastv2691176990399/moatad.js#moatClientLevel1=p-tTB93UFC5vepM&moatClientLevel2=597556&moatClientLevel3=394797&moatClientLevel4=1204720&uid=WjW2tQAOJEUKaYKXSwGCkQ                                                                                                                                           4
# https://z.moatads.com/iprospectusadidasdcm949238145220/moatad.js#moatClientLevel1=20560416&moatClientLevel2=2445008&moatClientLevel3=210642386&moatClientLevel4=95827831&zMoatG=ct=US&st=&city=0&dma=0&zp=&bw=4&zMoatADV=5094938&zMoatUSER=0                                                                                           4
# https://pagead2.googlesyndication.com/pagead/js/r20171206/r20170110/show_ads_impl.js                                                                                                                                                                                                                                                   4
# https://z.moatads.com/groupmvolvo744979952275/moatad.js#moatClientLevel1=10711790&moatClientLevel2=1659772&moatClientLevel3=143022661&moatClientLevel4=91533378&moatClientSlicer1=-&moatClientSlicer2=-                                                                                                                                4
# https://z.moatads.com/keplerpaypaldcm168224283233/moatad.js#moatClientLevel1=20289716&moatClientLevel2=3346219&moatClientLevel3=209398205&moatClientLevel4=94936955&zMoatG=ct=US&st=&city=0&dma=0&zp=&bw=4&zMoatUSER=AMsySZZroVOPhCBTjwvMwECXzIVp                                                                                      4
# http://d1ivexoxmp59q7.cloudfront.net/gap/live.js                                                                                                                                                                                                                                                                                       4
# https://static.adsafeprotected.com/main.17.4.49.js                                                                                                                                                                                                                                                                                     3
# http://imasdk.googleapis.com/js/sdkloader/ima3.js                                                                                                                                                                                                                                                                                      2
# https://www.youtube.com/yts/jsbin/www-embed-player-vflml4-Bf/www-embed-player.js                                                                                                                                                                                                                                                       2
# http://cps.zhcw.com:8002/zhcwcms/stat/front/stat.js                                                                                                                                                                                                                                                                                    2
# https://s0.2mdn.net/879366/express_html_inpage_rendering_lib_200_197.js                                                                                                                                                                                                                                                                2
# http://bdimg.share.baidu.com/static/api/js/base/tangram.js?v=37768233.js                                                                                                                                                                                                                                                               2
# http://pagead2.googlesyndication.com/pagead/show_companion_ad.js                                                                                                                                                                                                                                                                       2
# https://www.leiphone.com/static/api/js/base/tangram.js?v=37768233.js                                                                                                                                                                                                                                                                   2
# https://s0.2mdn.net/879366/express_html_inpage_rendering_lib_200_216.js                                                                                                                                                                                                                                                                2
# https://hm.baidu.com/hm.js?0f7e8686c8fcc36f05ce11b84012d5ee                                                                                                                                                                                                                                                                            2
# http://bat.bing.com/bat.js                                                                                                                                                                                                                                                                                                             2
# https://hm.baidu.com/hm.js?9e96f4699727fbeac49a7ce0f8ff2669                                                                                                                                                                                                                                                                            2
# /_/scs/shopping-verified-reviews-static/_/js/k=boq-shopping-verified-reviews.VerifiedReviewsGcrProxyUi.en_US.DwoKXA2JTCM.O/ck=boq-shopping-verified-reviews.VerifiedReviewsGcrProxyUi.14ay2tvzlwwh7.L.F4.O/m=syg,OJUrvb,syf,syi,_latency,FCpbqb,WhJNk/rt=j/d=0/excm=emptyview,_b,_tp/ed=1/rs=AC8lLkQC8gLvGkNHSRDrUqsSzT7G6sVjMw        2
# https://imasdk.googleapis.com/js/core/bridge3.187.0_en.html#goog_686858418                                                                                                                                                                                                                                                             2
# https://www.youtube.com/yts/jsbin/desktop_polymer-vfluTZ68Q/desktop_polymer.js                                                                                                                                                                                                                                                         2
# https://imasdk.googleapis.com/js/core/bridge3.187.0_en.html#goog_1137558894                                                                                                                                                                                                                                                            2
# https://tpc.googlesyndication.com/sodar/d5qAyLYU.js                                                                                                                                                                                                                                                                                    2
# http://www.google-analytics.com/ga.js                                                                                                                                                                                                                                                                                                  2
# https://hm.baidu.com/hm.js?56952b4e90931ba06a8f5b43cd39daeb                                                                                                                                                                                                                                                                            2
# http://hm.baidu.com/h.js?692bd5f9c07d3ebd0063062fb0d7622f                                                                                                                                                                                                                                                                              2
# https://zona.mobi/build/3.bundle-508a1ea12718028bdec3.js                                                                                                                                                                                                                                                                               2
# http://fx.cmbchina.com/scripts/sdc_cmb.js                                                                                                                                                                                                                                                                                              2
# https://s0.2mdn.net/879366/express_html_inpage_rendering_lib_200_200.js                                                                                                                                                                                                                                                                2
# http://s.globalsources.com/gsol/en/clean/static/webtrends.min.js                                                                                                                                                                                                                                                                       2
# http://ajax.googleapis.com/ajax/libs/swfobject/2.2/swfobject.js                                                                                                                                                                                                                                                                        1
# https://ssl.p.jwpcdn.com/player/v/7.2.4/jwpsrv.js                                                                                                                                                                                                                                                                                      1
# http://ssl.p.jwpcdn.com/player/v/7.7.4/jwpsrv.js                                                                                                                                                                                                                                                                                       1
# https://s.mobile.ir/Static/cache/clientres/cachefile_script_common_131522646443734760.js                                                                                                                                                                                                                                               1
# http://blog.bongacams.com/wp-includes/js/swfobject.js?ver=2.2-20120417                                                                                                                                                                                                                                                                 1
# https://libs.coremetrics.com/eluminate.js                                                                                                                                                                                                                                                                                              1
# http://blog.bongacams.com/wp-content/plugins/easy-video-player/lib/flowplayer.min.js?ver=4.8.2                                                                                                                                                                                                                                         1
# Name: script_url, dtype: int64

# %% [markdown]
# A lot of interesting scripts have come up. Some of these should be safe like those from google-analytics. fingerprint.js is definitely a fingerpringint script. What is "https://mc.yandex.ru/metrika/watch.js" ?

# %%
res_df = df_plugins[df_plugins.script_url.str.contains('https://mc.yandex.ru/metrika/watch.js')]
res_df
# Out:
#      arguments  in_iframe                                         location  \
# 793   {}        False      https://www.vjav.com/tags/masturbating-958/
# 797   {}        False      https://www.vjav.com/tags/masturbating-958/
# 798   {}        False      https://www.vjav.com/tags/masturbating-958/
# 799   {}        False      https://www.vjav.com/tags/masturbating-958/
# 800   {}        False      https://www.vjav.com/tags/masturbating-958/
# 801   {}        False      https://www.vjav.com/tags/masturbating-958/
# 802   {}        False      https://www.vjav.com/tags/masturbating-958/
# 803   {}        False      https://www.vjav.com/tags/masturbating-958/
# 804   {}        False      https://www.vjav.com/tags/masturbating-958/
# 805   {}        False      https://www.vjav.com/tags/masturbating-958/
# 806   {}        False      https://www.vjav.com/tags/masturbating-958/
# 807   {}        False      https://www.vjav.com/tags/masturbating-958/
# 808   {}        False      https://www.vjav.com/tags/masturbating-958/
# 841   {}        False      https://www.vjav.com/tags/masturbating-958/
# 845   {}        False      https://www.vjav.com/tags/masturbating-958/
# 846   {}        False      https://www.vjav.com/tags/masturbating-958/
# 847   {}        False      https://www.vjav.com/tags/masturbating-958/
# 848   {}        False      https://www.vjav.com/tags/masturbating-958/
# 849   {}        False      https://www.vjav.com/tags/masturbating-958/
# 850   {}        False      https://www.vjav.com/tags/masturbating-958/
# 851   {}        False      https://www.vjav.com/tags/masturbating-958/
# 852   {}        False      https://www.vjav.com/tags/masturbating-958/
# 853   {}        False      https://www.vjav.com/tags/masturbating-958/
# 854   {}        False      https://www.vjav.com/tags/masturbating-958/
# 873   {}        False      https://www.vjav.com/tags/masturbating-958/
# 874   {}        False      https://www.vjav.com/tags/masturbating-958/
# 875   {}        False      https://www.vjav.com/tags/masturbating-958/
# 876   {}        False      https://www.vjav.com/tags/masturbating-958/
# 877   {}        False      https://www.vjav.com/tags/masturbating-958/
# 878   {}        False      https://www.vjav.com/tags/masturbating-958/
# 879   {}        False      https://www.vjav.com/tags/masturbating-958/
# 880   {}        False      https://www.vjav.com/tags/masturbating-958/
# 881   {}        False      https://www.vjav.com/tags/masturbating-958/
# 882   {}        False      https://www.vjav.com/tags/masturbating-958/
# 3694  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3698  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3699  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3700  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3701  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3702  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3703  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3704  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3705  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3706  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3707  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3708  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3709  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3770  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3771  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3772  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3773  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3774  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3775  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3776  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3777  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3778  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 3779  {}        False      https://www.newchic.com/vintage-dresses-c-3664/
# 9089  {}        False      https://zona.mobi/movies/gadkii-ya-3
# 9093  {}        False      https://zona.mobi/movies/gadkii-ya-3
# 9094  {}        False      https://zona.mobi/movies/gadkii-ya-3
# 9095  {}        False      https://zona.mobi/movies/gadkii-ya-3
# 9096  {}        False      https://zona.mobi/movies/gadkii-ya-3
# 9097  {}        False      https://zona.mobi/movies/gadkii-ya-3
# 9098  {}        False      https://zona.mobi/movies/gadkii-ya-3
# 9099  {}        False      https://zona.mobi/movies/gadkii-ya-3
# 9100  {}        False      https://zona.mobi/movies/gadkii-ya-3
# 9101  {}        False      https://zona.mobi/movies/gadkii-ya-3
# 9102  {}        False      https://zona.mobi/movies/gadkii-ya-3
# 9103  {}        False      https://zona.mobi/movies/gadkii-ya-3
# 9104  {}        False      https://zona.mobi/movies/gadkii-ya-3
#
#      operation                             script_url  \
# 793   get       https://mc.yandex.ru/metrika/watch.js
# 797   get       https://mc.yandex.ru/metrika/watch.js
# 798   get       https://mc.yandex.ru/metrika/watch.js
# 799   get       https://mc.yandex.ru/metrika/watch.js
# 800   get       https://mc.yandex.ru/metrika/watch.js
# 801   get       https://mc.yandex.ru/metrika/watch.js
# 802   get       https://mc.yandex.ru/metrika/watch.js
# 803   get       https://mc.yandex.ru/metrika/watch.js
# 804   get       https://mc.yandex.ru/metrika/watch.js
# 805   get       https://mc.yandex.ru/metrika/watch.js
# 806   get       https://mc.yandex.ru/metrika/watch.js
# 807   get       https://mc.yandex.ru/metrika/watch.js
# 808   get       https://mc.yandex.ru/metrika/watch.js
# 841   get       https://mc.yandex.ru/metrika/watch.js
# 845   get       https://mc.yandex.ru/metrika/watch.js
# 846   get       https://mc.yandex.ru/metrika/watch.js
# 847   get       https://mc.yandex.ru/metrika/watch.js
# 848   get       https://mc.yandex.ru/metrika/watch.js
# 849   get       https://mc.yandex.ru/metrika/watch.js
# 850   get       https://mc.yandex.ru/metrika/watch.js
# 851   get       https://mc.yandex.ru/metrika/watch.js
# 852   get       https://mc.yandex.ru/metrika/watch.js
# 853   get       https://mc.yandex.ru/metrika/watch.js
# 854   get       https://mc.yandex.ru/metrika/watch.js
# 873   get       https://mc.yandex.ru/metrika/watch.js
# 874   get       https://mc.yandex.ru/metrika/watch.js
# 875   get       https://mc.yandex.ru/metrika/watch.js
# 876   get       https://mc.yandex.ru/metrika/watch.js
# 877   get       https://mc.yandex.ru/metrika/watch.js
# 878   get       https://mc.yandex.ru/metrika/watch.js
# 879   get       https://mc.yandex.ru/metrika/watch.js
# 880   get       https://mc.yandex.ru/metrika/watch.js
# 881   get       https://mc.yandex.ru/metrika/watch.js
# 882   get       https://mc.yandex.ru/metrika/watch.js
# 3694  get       https://mc.yandex.ru/metrika/watch.js
# 3698  get       https://mc.yandex.ru/metrika/watch.js
# 3699  get       https://mc.yandex.ru/metrika/watch.js
# 3700  get       https://mc.yandex.ru/metrika/watch.js
# 3701  get       https://mc.yandex.ru/metrika/watch.js
# 3702  get       https://mc.yandex.ru/metrika/watch.js
# 3703  get       https://mc.yandex.ru/metrika/watch.js
# 3704  get       https://mc.yandex.ru/metrika/watch.js
# 3705  get       https://mc.yandex.ru/metrika/watch.js
# 3706  get       https://mc.yandex.ru/metrika/watch.js
# 3707  get       https://mc.yandex.ru/metrika/watch.js
# 3708  get       https://mc.yandex.ru/metrika/watch.js
# 3709  get       https://mc.yandex.ru/metrika/watch.js
# 3770  get       https://mc.yandex.ru/metrika/watch.js
# 3771  get       https://mc.yandex.ru/metrika/watch.js
# 3772  get       https://mc.yandex.ru/metrika/watch.js
# 3773  get       https://mc.yandex.ru/metrika/watch.js
# 3774  get       https://mc.yandex.ru/metrika/watch.js
# 3775  get       https://mc.yandex.ru/metrika/watch.js
# 3776  get       https://mc.yandex.ru/metrika/watch.js
# 3777  get       https://mc.yandex.ru/metrika/watch.js
# 3778  get       https://mc.yandex.ru/metrika/watch.js
# 3779  get       https://mc.yandex.ru/metrika/watch.js
# 9089  get       https://mc.yandex.ru/metrika/watch.js
# 9093  get       https://mc.yandex.ru/metrika/watch.js
# 9094  get       https://mc.yandex.ru/metrika/watch.js
# 9095  get       https://mc.yandex.ru/metrika/watch.js
# 9096  get       https://mc.yandex.ru/metrika/watch.js
# 9097  get       https://mc.yandex.ru/metrika/watch.js
# 9098  get       https://mc.yandex.ru/metrika/watch.js
# 9099  get       https://mc.yandex.ru/metrika/watch.js
# 9100  get       https://mc.yandex.ru/metrika/watch.js
# 9101  get       https://mc.yandex.ru/metrika/watch.js
# 9102  get       https://mc.yandex.ru/metrika/watch.js
# 9103  get       https://mc.yandex.ru/metrika/watch.js
# 9104  get       https://mc.yandex.ru/metrika/watch.js
#
#                                                                      symbol  \
# 793   window.navigator.plugins[Shockwave Flash].name
# 797   window.navigator.plugins[Shockwave Flash].version
# 798   window.navigator.plugins[Shockwave Flash].description
# 799   window.navigator.plugins[Shockwave Flash].name
# 800   window.navigator.plugins[Shockwave Flash].version
# 801   window.navigator.plugins[Shockwave Flash].description
# 802   window.navigator.plugins[Shockwave Flash].filename
# 803   window.navigator.mimeTypes[application/futuresplash].type
# 804   window.navigator.mimeTypes[application/futuresplash].description
# 805   window.navigator.mimeTypes[application/futuresplash].suffixes
# 806   window.navigator.mimeTypes[application/x-shockwave-flash].type
# 807   window.navigator.mimeTypes[application/x-shockwave-flash].description
# 808   window.navigator.mimeTypes[application/x-shockwave-flash].suffixes
# 841   window.navigator.plugins[Shockwave Flash].name
# 845   window.navigator.plugins[Shockwave Flash].name
# 846   window.navigator.plugins[Shockwave Flash].version
# 847   window.navigator.plugins[Shockwave Flash].description
# 848   window.navigator.plugins[Shockwave Flash].filename
# 849   window.navigator.mimeTypes[application/futuresplash].type
# 850   window.navigator.mimeTypes[application/futuresplash].description
# 851   window.navigator.mimeTypes[application/futuresplash].suffixes
# 852   window.navigator.mimeTypes[application/x-shockwave-flash].type
# 853   window.navigator.mimeTypes[application/x-shockwave-flash].description
# 854   window.navigator.mimeTypes[application/x-shockwave-flash].suffixes
# 873   window.navigator.plugins[Shockwave Flash].name
# 874   window.navigator.plugins[Shockwave Flash].version
# 875   window.navigator.plugins[Shockwave Flash].description
# 876   window.navigator.plugins[Shockwave Flash].filename
# 877   window.navigator.mimeTypes[application/futuresplash].type
# 878   window.navigator.mimeTypes[application/futuresplash].description
# 879   window.navigator.mimeTypes[application/futuresplash].suffixes
# 880   window.navigator.mimeTypes[application/x-shockwave-flash].type
# 881   window.navigator.mimeTypes[application/x-shockwave-flash].description
# 882   window.navigator.mimeTypes[application/x-shockwave-flash].suffixes
# 3694  window.navigator.plugins[Shockwave Flash].name
# 3698  window.navigator.plugins[Shockwave Flash].version
# 3699  window.navigator.plugins[Shockwave Flash].description
# 3700  window.navigator.plugins[Shockwave Flash].name
# 3701  window.navigator.plugins[Shockwave Flash].version
# 3702  window.navigator.plugins[Shockwave Flash].description
# 3703  window.navigator.plugins[Shockwave Flash].filename
# 3704  window.navigator.mimeTypes[application/futuresplash].type
# 3705  window.navigator.mimeTypes[application/futuresplash].description
# 3706  window.navigator.mimeTypes[application/futuresplash].suffixes
# 3707  window.navigator.mimeTypes[application/x-shockwave-flash].type
# 3708  window.navigator.mimeTypes[application/x-shockwave-flash].description
# 3709  window.navigator.mimeTypes[application/x-shockwave-flash].suffixes
# 3770  window.navigator.plugins[Shockwave Flash].name
# 3771  window.navigator.plugins[Shockwave Flash].version
# 3772  window.navigator.plugins[Shockwave Flash].description
# 3773  window.navigator.plugins[Shockwave Flash].filename
# 3774  window.navigator.mimeTypes[application/futuresplash].type
# 3775  window.navigator.mimeTypes[application/futuresplash].description
# 3776  window.navigator.mimeTypes[application/futuresplash].suffixes
# 3777  window.navigator.mimeTypes[application/x-shockwave-flash].type
# 3778  window.navigator.mimeTypes[application/x-shockwave-flash].description
# 3779  window.navigator.mimeTypes[application/x-shockwave-flash].suffixes
# 9089  window.navigator.plugins[Shockwave Flash].name
# 9093  window.navigator.plugins[Shockwave Flash].version
# 9094  window.navigator.plugins[Shockwave Flash].description
# 9095  window.navigator.plugins[Shockwave Flash].name
# 9096  window.navigator.plugins[Shockwave Flash].version
# 9097  window.navigator.plugins[Shockwave Flash].description
# 9098  window.navigator.plugins[Shockwave Flash].filename
# 9099  window.navigator.mimeTypes[application/futuresplash].type
# 9100  window.navigator.mimeTypes[application/futuresplash].description
# 9101  window.navigator.mimeTypes[application/futuresplash].suffixes
# 9102  window.navigator.mimeTypes[application/x-shockwave-flash].type
# 9103  window.navigator.mimeTypes[application/x-shockwave-flash].description
# 9104  window.navigator.mimeTypes[application/x-shockwave-flash].suffixes
#
#                   time_stamp                     value_1000 location_domain  \
# 793  2017-12-16 03:35:09.284  Shockwave Flash                vjav.com
# 797  2017-12-16 03:35:09.288  28.0.0.126                     vjav.com
# 798  2017-12-16 03:35:09.288  Shockwave Flash 28.0 r0        vjav.com
# 799  2017-12-16 03:35:09.288  Shockwave Flash                vjav.com
# 800  2017-12-16 03:35:09.288  28.0.0.126                     vjav.com
# 801  2017-12-16 03:35:09.288  Shockwave Flash 28.0 r0        vjav.com
# 802  2017-12-16 03:35:09.288  libflashplayer.so              vjav.com
# 803  2017-12-16 03:35:09.289  application/futuresplash       vjav.com
# 804  2017-12-16 03:35:09.289  FutureSplash Player            vjav.com
# 805  2017-12-16 03:35:09.289  spl                            vjav.com
# 806  2017-12-16 03:35:09.289  application/x-shockwave-flash  vjav.com
# 807  2017-12-16 03:35:09.289  Shockwave Flash                vjav.com
# 808  2017-12-16 03:35:09.289  swf                            vjav.com
# 841  2017-12-16 03:35:09.309  Shockwave Flash                vjav.com
# 845  2017-12-16 03:35:09.310  Shockwave Flash                vjav.com
# 846  2017-12-16 03:35:09.310  28.0.0.126                     vjav.com
# 847  2017-12-16 03:35:09.310  Shockwave Flash 28.0 r0        vjav.com
# 848  2017-12-16 03:35:09.310  libflashplayer.so              vjav.com
# 849  2017-12-16 03:35:09.310  application/futuresplash       vjav.com
# 850  2017-12-16 03:35:09.310  FutureSplash Player            vjav.com
# 851  2017-12-16 03:35:09.311  spl                            vjav.com
# 852  2017-12-16 03:35:09.311  application/x-shockwave-flash  vjav.com
# 853  2017-12-16 03:35:09.311  Shockwave Flash                vjav.com
# 854  2017-12-16 03:35:09.311  swf                            vjav.com
# 873  2017-12-16 03:35:09.375  Shockwave Flash                vjav.com
# 874  2017-12-16 03:35:09.375  28.0.0.126                     vjav.com
# 875  2017-12-16 03:35:09.375  Shockwave Flash 28.0 r0        vjav.com
# 876  2017-12-16 03:35:09.375  libflashplayer.so              vjav.com
# 877  2017-12-16 03:35:09.375  application/futuresplash       vjav.com
# 878  2017-12-16 03:35:09.375  FutureSplash Player            vjav.com
# 879  2017-12-16 03:35:09.375  spl                            vjav.com
# 880  2017-12-16 03:35:09.375  application/x-shockwave-flash  vjav.com
# 881  2017-12-16 03:35:09.376  Shockwave Flash                vjav.com
# 882  2017-12-16 03:35:09.376  swf                            vjav.com
# 3694 2017-12-16 14:09:31.512  Shockwave Flash                newchic.com
# 3698 2017-12-16 14:09:31.514  28.0.0.126                     newchic.com
# 3699 2017-12-16 14:09:31.515  Shockwave Flash 28.0 r0        newchic.com
# 3700 2017-12-16 14:09:31.515  Shockwave Flash                newchic.com
# 3701 2017-12-16 14:09:31.515  28.0.0.126                     newchic.com
# 3702 2017-12-16 14:09:31.515  Shockwave Flash 28.0 r0        newchic.com
# 3703 2017-12-16 14:09:31.515  libflashplayer.so              newchic.com
# 3704 2017-12-16 14:09:31.515  application/futuresplash       newchic.com
# 3705 2017-12-16 14:09:31.515  FutureSplash Player            newchic.com
# 3706 2017-12-16 14:09:31.515  spl                            newchic.com
# 3707 2017-12-16 14:09:31.515  application/x-shockwave-flash  newchic.com
# 3708 2017-12-16 14:09:31.515  Shockwave Flash                newchic.com
# 3709 2017-12-16 14:09:31.516  swf                            newchic.com
# 3770 2017-12-16 14:09:46.540  Shockwave Flash                newchic.com
# 3771 2017-12-16 14:09:46.540  28.0.0.126                     newchic.com
# 3772 2017-12-16 14:09:46.540  Shockwave Flash 28.0 r0        newchic.com
# 3773 2017-12-16 14:09:46.540  libflashplayer.so              newchic.com
# 3774 2017-12-16 14:09:46.541  application/futuresplash       newchic.com
# 3775 2017-12-16 14:09:46.541  FutureSplash Player            newchic.com
# 3776 2017-12-16 14:09:46.541  spl                            newchic.com
# 3777 2017-12-16 14:09:46.541  application/x-shockwave-flash  newchic.com
# 3778 2017-12-16 14:09:46.543  Shockwave Flash                newchic.com
# 3779 2017-12-16 14:09:46.543  swf                            newchic.com
# 9089 2017-12-16 05:29:38.172  Shockwave Flash                zona.mobi
# 9093 2017-12-16 05:29:38.175  28.0.0.126                     zona.mobi
# 9094 2017-12-16 05:29:38.175  Shockwave Flash 28.0 r0        zona.mobi
# 9095 2017-12-16 05:29:38.176  Shockwave Flash                zona.mobi
# 9096 2017-12-16 05:29:38.176  28.0.0.126                     zona.mobi
# 9097 2017-12-16 05:29:38.176  Shockwave Flash 28.0 r0        zona.mobi
# 9098 2017-12-16 05:29:38.176  libflashplayer.so              zona.mobi
# 9099 2017-12-16 05:29:38.176  application/futuresplash       zona.mobi
# 9100 2017-12-16 05:29:38.177  FutureSplash Player            zona.mobi
# 9101 2017-12-16 05:29:38.177  spl                            zona.mobi
# 9102 2017-12-16 05:29:38.177  application/x-shockwave-flash  zona.mobi
# 9103 2017-12-16 05:29:38.177  Shockwave Flash                zona.mobi
# 9104 2017-12-16 05:29:38.177  swf                            zona.mobi
#
#      script_domain location_base_url
# 793   yandex.ru     www.vjav.com
# 797   yandex.ru     www.vjav.com
# 798   yandex.ru     www.vjav.com
# 799   yandex.ru     www.vjav.com
# 800   yandex.ru     www.vjav.com
# 801   yandex.ru     www.vjav.com
# 802   yandex.ru     www.vjav.com
# 803   yandex.ru     www.vjav.com
# 804   yandex.ru     www.vjav.com
# 805   yandex.ru     www.vjav.com
# 806   yandex.ru     www.vjav.com
# 807   yandex.ru     www.vjav.com
# 808   yandex.ru     www.vjav.com
# 841   yandex.ru     www.vjav.com
# 845   yandex.ru     www.vjav.com
# 846   yandex.ru     www.vjav.com
# 847   yandex.ru     www.vjav.com
# 848   yandex.ru     www.vjav.com
# 849   yandex.ru     www.vjav.com
# 850   yandex.ru     www.vjav.com
# 851   yandex.ru     www.vjav.com
# 852   yandex.ru     www.vjav.com
# 853   yandex.ru     www.vjav.com
# 854   yandex.ru     www.vjav.com
# 873   yandex.ru     www.vjav.com
# 874   yandex.ru     www.vjav.com
# 875   yandex.ru     www.vjav.com
# 876   yandex.ru     www.vjav.com
# 877   yandex.ru     www.vjav.com
# 878   yandex.ru     www.vjav.com
# 879   yandex.ru     www.vjav.com
# 880   yandex.ru     www.vjav.com
# 881   yandex.ru     www.vjav.com
# 882   yandex.ru     www.vjav.com
# 3694  yandex.ru     www.newchic.com
# 3698  yandex.ru     www.newchic.com
# 3699  yandex.ru     www.newchic.com
# 3700  yandex.ru     www.newchic.com
# 3701  yandex.ru     www.newchic.com
# 3702  yandex.ru     www.newchic.com
# 3703  yandex.ru     www.newchic.com
# 3704  yandex.ru     www.newchic.com
# 3705  yandex.ru     www.newchic.com
# 3706  yandex.ru     www.newchic.com
# 3707  yandex.ru     www.newchic.com
# 3708  yandex.ru     www.newchic.com
# 3709  yandex.ru     www.newchic.com
# 3770  yandex.ru     www.newchic.com
# 3771  yandex.ru     www.newchic.com
# 3772  yandex.ru     www.newchic.com
# 3773  yandex.ru     www.newchic.com
# 3774  yandex.ru     www.newchic.com
# 3775  yandex.ru     www.newchic.com
# 3776  yandex.ru     www.newchic.com
# 3777  yandex.ru     www.newchic.com
# 3778  yandex.ru     www.newchic.com
# 3779  yandex.ru     www.newchic.com
# 9089  yandex.ru     zona.mobi
# 9093  yandex.ru     zona.mobi
# 9094  yandex.ru     zona.mobi
# 9095  yandex.ru     zona.mobi
# 9096  yandex.ru     zona.mobi
# 9097  yandex.ru     zona.mobi
# 9098  yandex.ru     zona.mobi
# 9099  yandex.ru     zona.mobi
# 9100  yandex.ru     zona.mobi
# 9101  yandex.ru     zona.mobi
# 9102  yandex.ru     zona.mobi
# 9103  yandex.ru     zona.mobi
# 9104  yandex.ru     zona.mobi

# %% [markdown]
# Let us check how does it look when grouped by location

# %%
Gres = res_df.groupby('location')
Gres.describe()
# Out:
#                                                 arguments                  \
#                                                     count unique top freq
# location
# https://www.newchic.com/vintage-dresses-c-3664/  23        1      {}  23
# https://www.vjav.com/tags/masturbating-958/      34        1      {}  34
# https://zona.mobi/movies/gadkii-ya-3             13        1      {}  13
#
#                                                            in_iframe         \
#                                                 first last     count unique
# location
# https://www.newchic.com/vintage-dresses-c-3664/  NaN   NaN  23        1
# https://www.vjav.com/tags/masturbating-958/      NaN   NaN  34        1
# https://zona.mobi/movies/gadkii-ya-3             NaN   NaN  13        1
#
#                                                                         \
#                                                    top freq first last
# location
# https://www.newchic.com/vintage-dresses-c-3664/  False  23   NaN   NaN
# https://www.vjav.com/tags/masturbating-958/      False  34   NaN   NaN
# https://zona.mobi/movies/gadkii-ya-3             False  13   NaN   NaN
#
#                                                 operation                   \
#                                                     count unique  top freq
# location
# https://www.newchic.com/vintage-dresses-c-3664/  23        1      get  23
# https://www.vjav.com/tags/masturbating-958/      34        1      get  34
# https://zona.mobi/movies/gadkii-ya-3             13        1      get  13
#
#                                                            script_url         \
#                                                 first last      count unique
# location
# https://www.newchic.com/vintage-dresses-c-3664/  NaN   NaN  23         1
# https://www.vjav.com/tags/masturbating-958/      NaN   NaN  34         1
# https://zona.mobi/movies/gadkii-ya-3             NaN   NaN  13         1
#
#                                                                                         \
#                                                                                    top
# location
# https://www.newchic.com/vintage-dresses-c-3664/  https://mc.yandex.ru/metrika/watch.js
# https://www.vjav.com/tags/masturbating-958/      https://mc.yandex.ru/metrika/watch.js
# https://zona.mobi/movies/gadkii-ya-3             https://mc.yandex.ru/metrika/watch.js
#
#                                                                 symbol         \
#                                                 freq first last  count unique
# location
# https://www.newchic.com/vintage-dresses-c-3664/  23   NaN   NaN  23     10
# https://www.vjav.com/tags/masturbating-958/      34   NaN   NaN  34     10
# https://zona.mobi/movies/gadkii-ya-3             13   NaN   NaN  13     10
#
#                                                                                                  \
#                                                                                             top
# location
# https://www.newchic.com/vintage-dresses-c-3664/  window.navigator.plugins[Shockwave Flash].name
# https://www.vjav.com/tags/masturbating-958/      window.navigator.plugins[Shockwave Flash].name
# https://zona.mobi/movies/gadkii-ya-3             window.navigator.plugins[Shockwave Flash].name
#
#                                                                 time_stamp  \
#                                                 freq first last      count
# location
# https://www.newchic.com/vintage-dresses-c-3664/  3    NaN   NaN  23
# https://www.vjav.com/tags/masturbating-958/      5    NaN   NaN  34
# https://zona.mobi/movies/gadkii-ya-3             2    NaN   NaN  13
#
#                                                         \
#                                                 unique
# location
# https://www.newchic.com/vintage-dresses-c-3664/  7
# https://www.vjav.com/tags/masturbating-958/      8
# https://zona.mobi/movies/gadkii-ya-3             4
#
#                                                                              \
#                                                                         top
# location
# https://www.newchic.com/vintage-dresses-c-3664/  2017-12-16 14:09:31.515000
# https://www.vjav.com/tags/masturbating-958/      2017-12-16 03:35:09.375000
# https://zona.mobi/movies/gadkii-ya-3             2017-12-16 05:29:38.176000
#
#                                                       \
#                                                 freq
# location
# https://www.newchic.com/vintage-dresses-c-3664/  10
# https://www.vjav.com/tags/masturbating-958/      8
# https://zona.mobi/movies/gadkii-ya-3             5
#
#                                                                              \
#                                                                       first
# location
# https://www.newchic.com/vintage-dresses-c-3664/  2017-12-16 14:09:31.512000
# https://www.vjav.com/tags/masturbating-958/      2017-12-16 03:35:09.284000
# https://zona.mobi/movies/gadkii-ya-3             2017-12-16 05:29:38.172000
#
#                                                                              \
#                                                                        last
# location
# https://www.newchic.com/vintage-dresses-c-3664/  2017-12-16 14:09:46.543000
# https://www.vjav.com/tags/masturbating-958/      2017-12-16 03:35:09.376000
# https://zona.mobi/movies/gadkii-ya-3             2017-12-16 05:29:38.177000
#
#                                                 value_1000         \
#                                                      count unique
# location
# https://www.newchic.com/vintage-dresses-c-3664/  23         9
# https://www.vjav.com/tags/masturbating-958/      34         9
# https://zona.mobi/movies/gadkii-ya-3             13         9
#
#                                                                              \
#                                                              top freq first
# location
# https://www.newchic.com/vintage-dresses-c-3664/  Shockwave Flash  5    NaN
# https://www.vjav.com/tags/masturbating-958/      Shockwave Flash  8    NaN
# https://zona.mobi/movies/gadkii-ya-3             Shockwave Flash  3    NaN
#
#                                                      location_domain         \
#                                                 last           count unique
# location
# https://www.newchic.com/vintage-dresses-c-3664/  NaN  23              1
# https://www.vjav.com/tags/masturbating-958/      NaN  34              1
# https://zona.mobi/movies/gadkii-ya-3             NaN  13              1
#
#                                                                               \
#                                                          top freq first last
# location
# https://www.newchic.com/vintage-dresses-c-3664/  newchic.com  23   NaN   NaN
# https://www.vjav.com/tags/masturbating-958/      vjav.com     34   NaN   NaN
# https://zona.mobi/movies/gadkii-ya-3             zona.mobi    13   NaN   NaN
#
#                                                 script_domain         \
#                                                         count unique
# location
# https://www.newchic.com/vintage-dresses-c-3664/  23            1
# https://www.vjav.com/tags/masturbating-958/      34            1
# https://zona.mobi/movies/gadkii-ya-3             13            1
#
#                                                                             \
#                                                        top freq first last
# location
# https://www.newchic.com/vintage-dresses-c-3664/  yandex.ru  23   NaN   NaN
# https://www.vjav.com/tags/masturbating-958/      yandex.ru  34   NaN   NaN
# https://zona.mobi/movies/gadkii-ya-3             yandex.ru  13   NaN   NaN
#
#                                                 location_base_url         \
#                                                             count unique
# location
# https://www.newchic.com/vintage-dresses-c-3664/  23                1
# https://www.vjav.com/tags/masturbating-958/      34                1
# https://zona.mobi/movies/gadkii-ya-3             13                1
#
#                                                                              \
#                                                              top freq first
# location
# https://www.newchic.com/vintage-dresses-c-3664/  www.newchic.com  23   NaN
# https://www.vjav.com/tags/masturbating-958/      www.vjav.com     34   NaN
# https://zona.mobi/movies/gadkii-ya-3             zona.mobi        13   NaN
#
#
#                                                 last
# location
# https://www.newchic.com/vintage-dresses-c-3664/  NaN
# https://www.vjav.com/tags/masturbating-958/      NaN
# https://zona.mobi/movies/gadkii-ya-3             NaN

# %% [markdown]
# So this script always asks for same 10 symbols which we can see below. This talks only about flash player and wants to know the name, version, description etc. Can we fingerprint using this? Yes but should not be very unique. What other things can this script be collecting??

# %%
res_df['symbol'].value_counts()
# Out:
# window.navigator.plugins[Shockwave Flash].name                           10
# window.navigator.plugins[Shockwave Flash].description                    9
# window.navigator.plugins[Shockwave Flash].version                        9
# window.navigator.mimeTypes[application/x-shockwave-flash].description    6
# window.navigator.mimeTypes[application/futuresplash].type                6
# window.navigator.mimeTypes[application/futuresplash].description         6
# window.navigator.mimeTypes[application/x-shockwave-flash].suffixes       6
# window.navigator.plugins[Shockwave Flash].filename                       6
# window.navigator.mimeTypes[application/x-shockwave-flash].type           6
# window.navigator.mimeTypes[application/futuresplash].suffixes            6
# Name: symbol, dtype: int64

# %% [markdown]
# Now I am little confused. On one hand this script is asking a lot of information about the Flash players on client side, but this could be because of the kind of sites it is hosted on and they require precise knowledge about flashplayers to render the content correctly. It could though also be doing fingerprinting by collecting this information. Who knows! :(
#
# I took a look at other scripts which we found above and found an interesting one: http://dthq3mor50viz.cloudfront.net/zbajck9faU.js. This is a JS tracker for Snowplow which is a web tracking service. [Here](https://github.com/snowplow/snowplow/wiki/1-General-parameters-for-the-Javascript-tracker) is a documentation of the script. Yay! we found another script which does fingerprinting. We can add this to our list of `hs-analytics`, `/akam/` and `fingeprint.js`. This analysis got us another fingerprinting script (answer to Q1) which is definitely using plugin information (answer to Q2).

# %% [markdown]
# ## Browser fingerprinting using fingerprint.js
# fingerprint.j2 or fingerprint2.js are common javascript libraries used for fingerprinting. They query a bunch of features from the client and produces a hashcode using murmur hash functions based on the query results. This assigns a unique (almost) hash to each device and can be used to track client across websites.
#
# Here I am interested in looking at all calls of fingerprint2.js. I want to understand what all arguments and values are associated with calls to fingerprint2.js. Can I infer a pattern with such calls and filter the calls to fingerprint2.js without explicitly looking for it?
#
# In [#34](https://github.com/mozilla/overscripted/issues/34), Sarah has suggested to use "Cwm fjordbank glyphs vext quiz" in argument_0, but I have found that the above string is a panagram and can be used in other scripts as well and not just fingerprint.js. Therefore I have looked for "fingerprint" in the URL column of the dataset.

# %%
FingerPrint = Rdf[Rdf.script_url.str.contains('fingerprint')]
#T = df[df.argument_0.str.contains('Cwm fjordbank glyphs vext quiz')]
FingerPrint
# Out:
#      arguments  in_iframe  \
# 2660  {}        False
# 2661  {}        False
# 2662  {}        False
# 2663  {}        False
# 2664  {}        False
# 2665  {}        False
# 2666  {}        False
# 2667  {}        False
# 2668  {}        False
# 2669  {}        False
# 2670  {}        False
# 2671  {}        False
# 2672  {}        False
# 2673  {}        False
# 2674  {}        False
# 2675  {}        False
# 2676  {}        False
# 2677  {}        False
# 2678  {}        False
#
#                                                                   location  \
# 2660  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# 2661  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# 2662  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# 2663  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# 2664  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# 2665  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# 2666  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# 2667  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# 2668  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# 2669  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# 2670  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# 2671  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# 2672  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# 2673  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# 2674  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# 2675  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# 2676  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# 2677  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# 2678  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
#
#      operation  \
# 2660  get
# 2661  get
# 2662  get
# 2663  get
# 2664  get
# 2665  get
# 2666  get
# 2667  get
# 2668  get
# 2669  get
# 2670  get
# 2671  get
# 2672  get
# 2673  get
# 2674  get
# 2675  get
# 2676  get
# 2677  get
# 2678  get
#
#                                                                                 script_url  \
# 2660  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
# 2661  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
# 2662  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
# 2663  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
# 2664  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
# 2665  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
# 2666  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
# 2667  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
# 2668  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
# 2669  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
# 2670  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
# 2671  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
# 2672  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
# 2673  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
# 2674  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
# 2675  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
# 2676  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
# 2677  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
# 2678  http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js
#
#                                                                   symbol  \
# 2660  window.navigator.userAgent
# 2661  window.navigator.language
# 2662  window.screen.colorDepth
# 2663  window.sessionStorage
# 2664  window.localStorage
# 2665  window.navigator.platform
# 2666  window.navigator.doNotTrack
# 2667  window.navigator.appName
# 2668  window.navigator.appName
# 2669  window.navigator.userAgent
# 2670  window.navigator.plugins[Shockwave Flash].length
# 2671  window.navigator.plugins[Shockwave Flash].length
# 2672  window.navigator.plugins[Shockwave Flash].length
# 2673  window.navigator.mimeTypes[application/x-shockwave-flash].type
# 2674  window.navigator.mimeTypes[application/x-shockwave-flash].suffixes
# 2675  window.navigator.mimeTypes[application/futuresplash].type
# 2676  window.navigator.mimeTypes[application/futuresplash].suffixes
# 2677  window.navigator.plugins[Shockwave Flash].name
# 2678  window.navigator.plugins[Shockwave Flash].description
#
#                   time_stamp  \
# 2660 2017-12-16 17:01:59.862
# 2661 2017-12-16 17:01:59.862
# 2662 2017-12-16 17:01:59.862
# 2663 2017-12-16 17:01:59.862
# 2664 2017-12-16 17:01:59.862
# 2665 2017-12-16 17:01:59.864
# 2666 2017-12-16 17:01:59.865
# 2667 2017-12-16 17:01:59.865
# 2668 2017-12-16 17:01:59.865
# 2669 2017-12-16 17:01:59.866
# 2670 2017-12-16 17:01:59.866
# 2671 2017-12-16 17:01:59.867
# 2672 2017-12-16 17:01:59.867
# 2673 2017-12-16 17:01:59.868
# 2674 2017-12-16 17:01:59.869
# 2675 2017-12-16 17:01:59.869
# 2676 2017-12-16 17:01:59.869
# 2677 2017-12-16 17:01:59.869
# 2678 2017-12-16 17:01:59.869
#
#                                                                 value_1000  \
# 2660  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
# 2661  en-US
# 2662  24
# 2663  {}
# 2664  {"alerte_tracking":"{\"data\":true,\"timeout\":1544979718260}"}
# 2665  Linux x86_64
# 2666  unspecified
# 2667  Netscape
# 2668  Netscape
# 2669  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
# 2670  2
# 2671  2
# 2672  2
# 2673  application/x-shockwave-flash
# 2674  swf
# 2675  application/futuresplash
# 2676  spl
# 2677  Shockwave Flash
# 2678  Shockwave Flash 28.0 r0
#
#      location_domain script_domain location_base_url
# 2660  lemonde.fr      lemde.fr      www.lemonde.fr
# 2661  lemonde.fr      lemde.fr      www.lemonde.fr
# 2662  lemonde.fr      lemde.fr      www.lemonde.fr
# 2663  lemonde.fr      lemde.fr      www.lemonde.fr
# 2664  lemonde.fr      lemde.fr      www.lemonde.fr
# 2665  lemonde.fr      lemde.fr      www.lemonde.fr
# 2666  lemonde.fr      lemde.fr      www.lemonde.fr
# 2667  lemonde.fr      lemde.fr      www.lemonde.fr
# 2668  lemonde.fr      lemde.fr      www.lemonde.fr
# 2669  lemonde.fr      lemde.fr      www.lemonde.fr
# 2670  lemonde.fr      lemde.fr      www.lemonde.fr
# 2671  lemonde.fr      lemde.fr      www.lemonde.fr
# 2672  lemonde.fr      lemde.fr      www.lemonde.fr
# 2673  lemonde.fr      lemde.fr      www.lemonde.fr
# 2674  lemonde.fr      lemde.fr      www.lemonde.fr
# 2675  lemonde.fr      lemde.fr      www.lemonde.fr
# 2676  lemonde.fr      lemde.fr      www.lemonde.fr
# 2677  lemonde.fr      lemde.fr      www.lemonde.fr
# 2678  lemonde.fr      lemde.fr      www.lemonde.fr

# %% [markdown]
# If you see the table above and look at the timestamps, almost all calls are made around same time and it is querying a bunch of attributes to produce a hash. Looking at the calls above and comparing it with counts in the dataset [here](https://github.com/mozilla/overscripted/blob/master/data_prep/symbol_counts.csv) I see that symbols like `window.navigator.doNotTrack`, `window.navigator.plugins[Shockwave Flash].length`, `window.navigator.mimeTypes[application/futuresplash].suffixes`	are fairly rare when compared to `window.sessionStorage` or `window.navigator.userAgent`. I want to test if I just filter on rare symbols can I catch `fingerprint.js` calls? Hypothesis is that these rare calls to symbols is only done by fingerprinting scripts.

# %%
sessionStorage = Rdf[Rdf.symbol == "window.sessionStorage"]
doNotTrack = Rdf[Rdf.symbol == "window.navigator.doNotTrack"]
ShockWaveLength = Rdf[Rdf.symbol.str.contains("[Shockwave Flash].length")]
FuturesplashSuffixes = Rdf[Rdf.symbol == "window.navigator.mimeTypes[application/futuresplash].suffixes"]
FuturesplashType = Rdf[Rdf.symbol == "window.navigator.mimeTypes[application/futuresplash].type"]
print("FingerPrint: ", len(FingerPrint))
print("sessionStorage: ",len(sessionStorage))
print("ShockWaveLength: ",len(ShockWaveLength))
print("doNotTrack: ",len(doNotTrack))
print("FuturesplashSuffixes: ",len(FuturesplashSuffixes))
print("FuturesplashType: ",len(FuturesplashType))
# Out:
# FingerPrint:  19
# sessionStorage:  236
# ShockWaveLength:  78
# doNotTrack:  21
# FuturesplashSuffixes:  9
# FuturesplashType:  13

# %% [markdown]
# As expected `sessionStorage` is pretty common followed by `ShockWaveLength`. The count reduces a lot for `FingerPrint`, `doNotTrack` and `FuturesplashSuffixes`. I am interested to know which all scripts use `doNotTrack` and `FuturesplashSuffixes`

# %% [markdown]
# ### Scripts with call to doNotTrack

# %%
print(doNotTrack.script_url.unique())
print(len(doNotTrack.script_url.unique()))
# Out:
# ['http://dthq3mor50viz.cloudfront.net/zbajck9faU.js'
#  'https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1'
#  'http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js'
#  'http://www.gap.com/akam/10/6e136b78'
#  'https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js'
#  'https://script.crazyegg.com/pages/scripts/0014/1290.js?420406'
#  'http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js'
#  'https://script.crazyegg.com/pages/scripts/0032/8588.js?420389'
#  'https://script.crazyegg.com/pages/scripts/0013/0568.js?420385'
#  'https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js']
# 10

# %%
print(doNotTrack.script_domain.unique())
print(len(doNotTrack.script_domain.unique()))
# Out:
# ['cloudfront.net' 'krxd.net' 'lemde.fr' 'gap.com' 'disquscdn.com'
#  'crazyegg.com' 'break.com' 'alicdn.com']
# 8

# %% [markdown]
# There are 9 unique `script_urls` in the sample dataset and 8 unique `script_domains`. This feature has caught *fingerprint.js* and *akam* scripts and have also suggested other scripts which can be potentially doing some kind of fingerprinting. I would need to do some more background search on the kind of domains which we see here. Some of these like cloudfront.net are CDNs and can be overlooked.

# %%
doNotTrack.groupby(['script_url']).describe()
# Out:
#                                                                                      arguments  \
#                                                                                          count
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        2
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   2
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  6
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              5
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                              \
#                                                                                      unique
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  1
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              1
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                           \
#                                                                                      top
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     {}
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        {}
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  {}
# http://www.gap.com/akam/10/6e136b78                                                   {}
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  {}
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              {}
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 {}
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         {}
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         {}
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         {}
#
#                                                                                            \
#                                                                                      freq
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        2
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   2
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  6
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              5
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                             \
#                                                                                      first
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  NaN
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              NaN
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 NaN
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         NaN
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         NaN
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         NaN
#
#                                                                                            \
#                                                                                      last
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  NaN
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              NaN
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 NaN
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         NaN
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         NaN
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         NaN
#
#                                                                                      in_iframe  \
#                                                                                          count
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        2
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   2
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  6
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              5
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                              \
#                                                                                      unique
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  1
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              2
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                              \
#                                                                                         top
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     False
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        False
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  False
# http://www.gap.com/akam/10/6e136b78                                                   False
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  True
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              False
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 False
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         False
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         False
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         False
#
#                                                                                            \
#                                                                                      freq
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        2
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   2
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  6
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              3
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                             \
#                                                                                      first
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  NaN
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              NaN
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 NaN
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         NaN
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         NaN
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         NaN
#
#                                                                                            \
#                                                                                      last
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  NaN
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              NaN
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 NaN
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         NaN
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         NaN
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         NaN
#
#                                                                                      location  \
#                                                                                         count
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        2
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   2
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  6
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              5
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                              \
#                                                                                      unique
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  3
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              2
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                             \
#                                                                                                                                                                                                                                                                                                                                                                                                                                        top
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     http://www.ufc.ca/media/Submission-of-the-Week-Mickey-Gall-vs-Mike-Jackson
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        http://www.addictinggames.com/help/parents.jsp
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# http://www.gap.com/akam/10/6e136b78                                                   http://www.gap.com/browse/category.do?cid=1096402&sop=true
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  https://disqus.com/embed/comments/?base=default&f=sofifa&t_u=http%3A%2F%2Fsofifa.com%2Fplayer%2F231443&t_e=O.%20Demb%C3%A9l%C3%A9%20-%20Player%20-%20SoFIFA&t_d=Ousmane%20Demb%C3%A9l%C3%A9%20FIFA%2018%20Dec%2014%2C%202017%20SoFIFA&t_t=O.%20Demb%C3%A9l%C3%A9%20-%20Player%20-%20SoFIFA&s_o=default&l=en#version=8e0609b122e4529350708e7c7b2d6a12
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              https://www.autoscout24.it/auto/audi/audi-a4/
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 https://list.tmall.com/search_product.htm?abbucket=&pic_detail=1&active=1&acm=lb-zebra-22355-807833.1003.4.764609&sort=s&industryCatId=50106419&spm=a220m.1000858.1000721.5.8puO4R&abtest=&pos=13&cat=52588013&from=sn_1_cat&style=g&search_condition=55&scm=1003.4.lb-zebra-22355-807833.OTHER_147327151378711_764609&aldid=226900
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         https://www.pwc.com/gx/en/industries/transportation-logistics.html
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         https://www.backcountry.com/travel?show=all&p=gender%3Amale%7Cattr_age%3Aadult&nf=12
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         https://www.rakuten.com.tw/search/%E5%B0%8F%E7%B1%B3/
#
#                                                                                            \
#                                                                                      freq
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        2
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   2
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  2
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              3
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                             \
#                                                                                      first
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  NaN
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              NaN
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 NaN
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         NaN
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         NaN
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         NaN
#
#                                                                                            \
#                                                                                      last
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  NaN
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              NaN
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 NaN
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         NaN
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         NaN
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         NaN
#
#                                                                                      operation  \
#                                                                                          count
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        2
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   2
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  6
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              5
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                              \
#                                                                                      unique
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  1
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              1
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                            \
#                                                                                       top
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     get
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        get
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  get
# http://www.gap.com/akam/10/6e136b78                                                   get
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  get
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              get
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 get
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         get
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         get
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         get
#
#                                                                                            \
#                                                                                      freq
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        2
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   2
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  6
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              5
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                             \
#                                                                                      first
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  NaN
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              NaN
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 NaN
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         NaN
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         NaN
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         NaN
#
#                                                                                            \
#                                                                                      last
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  NaN
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              NaN
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 NaN
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         NaN
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         NaN
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         NaN
#
#                                                                                      symbol  \
#                                                                                       count
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        2
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   2
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  6
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              5
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                              \
#                                                                                      unique
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  1
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              1
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                                                    \
#                                                                                                               top
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     window.navigator.doNotTrack
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        window.navigator.doNotTrack
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  window.navigator.doNotTrack
# http://www.gap.com/akam/10/6e136b78                                                   window.navigator.doNotTrack
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  window.navigator.doNotTrack
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              window.navigator.doNotTrack
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 window.navigator.doNotTrack
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         window.navigator.doNotTrack
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         window.navigator.doNotTrack
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         window.navigator.doNotTrack
#
#                                                                                            \
#                                                                                      freq
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        2
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   2
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  6
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              5
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                             \
#                                                                                      first
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  NaN
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              NaN
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 NaN
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         NaN
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         NaN
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         NaN
#
#                                                                                            \
#                                                                                      last
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  NaN
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              NaN
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 NaN
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         NaN
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         NaN
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         NaN
#
#                                                                                      time_stamp  \
#                                                                                           count
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        2
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   2
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  6
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              5
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                              \
#                                                                                      unique
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  3
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              5
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                                                   \
#                                                                                                              top
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     2017-12-16 00:17:13.993000
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        2017-12-16 22:55:09.661000
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  2017-12-16 17:01:59.865000
# http://www.gap.com/akam/10/6e136b78                                                   2017-12-16 22:51:16.026000
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  2017-12-16 02:09:35.686000
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              2017-12-16 23:00:21.948000
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 2017-12-16 17:23:58.982000
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         2017-12-16 01:54:07.386000
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         2017-12-16 22:22:45.461000
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         2017-12-16 05:05:13.394000
#
#                                                                                            \
#                                                                                      freq
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        2
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   2
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  2
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              1
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                                                   \
#                                                                                                            first
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     2017-12-16 00:17:13.993000
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        2017-12-16 22:55:09.661000
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  2017-12-16 17:01:59.865000
# http://www.gap.com/akam/10/6e136b78                                                   2017-12-16 22:51:16.026000
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  2017-12-16 02:09:35.686000
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              2017-12-16 07:32:34.471000
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 2017-12-16 17:23:58.982000
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         2017-12-16 01:54:07.386000
# ...
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  NaN
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              NaN
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 NaN
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         NaN
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         NaN
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         NaN
#
#                                                                                      script_domain  \
#                                                                                              count
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        2
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   2
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  6
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              5
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                              \
#                                                                                      unique
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  1
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              1
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                                       \
#                                                                                                  top
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     cloudfront.net
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        break.com
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  lemde.fr
# http://www.gap.com/akam/10/6e136b78                                                   gap.com
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  disquscdn.com
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              krxd.net
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 alicdn.com
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         crazyegg.com
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         crazyegg.com
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         crazyegg.com
#
#                                                                                            \
#                                                                                      freq
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        2
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   2
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  6
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              5
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                             \
#                                                                                      first
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  NaN
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              NaN
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 NaN
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         NaN
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         NaN
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         NaN
#
#                                                                                            \
#                                                                                      last
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  NaN
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              NaN
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 NaN
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         NaN
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         NaN
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         NaN
#
#                                                                                      location_base_url  \
#                                                                                                  count
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        2
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   2
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  6
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              5
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                              \
#                                                                                      unique
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  1
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              2
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                                               \
#                                                                                                          top
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     www.ufc.ca
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        www.addictinggames.com
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  www.lemonde.fr
# http://www.gap.com/akam/10/6e136b78                                                   www.gap.com
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  disqus.com
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              www.autoscout24.it
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 list.tmall.com
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         www.pwc.com
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         www.backcountry.com
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         www.rakuten.com.tw
#
#                                                                                            \
#                                                                                      freq
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        2
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   2
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  6
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              3
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 1
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         1
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         1
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         1
#
#                                                                                             \
#                                                                                      first
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  NaN
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              NaN
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 NaN
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         NaN
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         NaN
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         NaN
#
#
#                                                                                      last
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://media1.break.com/campaigns/global_lib/defy-prebid/0.31.0/defy_prebid.js        NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://c.disquscdn.com/next/embed/lounge.bundle.8d07a4869c3ec17ee1881ae6bd353027.js  NaN
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1              NaN
# https://g.alicdn.com/secdev/sufei_data/3.2.2/index.js                                 NaN
# https://script.crazyegg.com/pages/scripts/0013/0568.js?420385                         NaN
# https://script.crazyegg.com/pages/scripts/0014/1290.js?420406                         NaN
# https://script.crazyegg.com/pages/scripts/0032/8588.js?420389                         NaN

# %% [markdown]
# ### Scripts with call to FuturesplashSuffixes

# %%
print(FuturesplashSuffixes.script_url.unique())
print(len(FuturesplashSuffixes.script_url.unique()))
# Out:
# ['http://dthq3mor50viz.cloudfront.net/zbajck9faU.js'
#  'https://mc.yandex.ru/metrika/watch.js'
#  'http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js'
#  'http://www.gap.com/akam/10/6e136b78']
# 4

# %%
print(FuturesplashSuffixes.script_domain.unique())
print(len(FuturesplashSuffixes.script_domain.unique()))
# Out:
# ['cloudfront.net' 'yandex.ru' 'lemde.fr' 'gap.com']
# 4

# %% [markdown]
# There are 4 unique script_urls in the sample dataset and 4 unique script_domains. This feature has caught fingerprint.js and akam scripts and have also suggested other scripts like `https://mc.yandex.ru/metrika/watch.js` and `http://dthq3mor50viz.cloudfront.net/zbajck9faU.js`. This feature is very selective and useful because it has restricted the dataset to only suspicious scripts. I would definitely like to keep this feature in my heuristic to detect browser attribute fingerprinting.

# %%
FuturesplashSuffixes.groupby(['script_url']).describe()
# Out:
#                                                                                      arguments  \
#                                                                                          count
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 6
#
#                                                                                              \
#                                                                                      unique
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 1
#
#                                                                                           \
#                                                                                      top
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     {}
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  {}
# http://www.gap.com/akam/10/6e136b78                                                   {}
# https://mc.yandex.ru/metrika/watch.js                                                 {}
#
#                                                                                            \
#                                                                                      freq
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 6
#
#                                                                                             \
#                                                                                      first
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://mc.yandex.ru/metrika/watch.js                                                 NaN
#
#                                                                                            \
#                                                                                      last
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://mc.yandex.ru/metrika/watch.js                                                 NaN
#
#                                                                                      in_iframe  \
#                                                                                          count
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 6
#
#                                                                                              \
#                                                                                      unique
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 1
#
#                                                                                              \
#                                                                                         top
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     False
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  False
# http://www.gap.com/akam/10/6e136b78                                                   False
# https://mc.yandex.ru/metrika/watch.js                                                 False
#
#                                                                                            \
#                                                                                      freq
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 6
#
#                                                                                             \
#                                                                                      first
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://mc.yandex.ru/metrika/watch.js                                                 NaN
#
#                                                                                            \
#                                                                                      last
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://mc.yandex.ru/metrika/watch.js                                                 NaN
#
#                                                                                      location  \
#                                                                                         count
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 6
#
#                                                                                              \
#                                                                                      unique
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 3
#
#                                                                                                                                                                   \
#                                                                                                                                                              top
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     http://www.ufc.ca/media/Submission-of-the-Week-Mickey-Gall-vs-Mike-Jackson
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  http://www.lemonde.fr/service/licence_et_droits_de_reproduction.html
# http://www.gap.com/akam/10/6e136b78                                                   http://www.gap.com/browse/category.do?cid=1096402&sop=true
# https://mc.yandex.ru/metrika/watch.js                                                 https://www.vjav.com/tags/masturbating-958/
#
#                                                                                            \
#                                                                                      freq
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 3
#
#                                                                                             \
#                                                                                      first
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://mc.yandex.ru/metrika/watch.js                                                 NaN
#
#                                                                                            \
#                                                                                      last
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://mc.yandex.ru/metrika/watch.js                                                 NaN
#
#                                                                                      operation  \
#                                                                                          count
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 6
#
#                                                                                              \
#                                                                                      unique
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 1
#
#                                                                                            \
#                                                                                       top
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     get
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  get
# http://www.gap.com/akam/10/6e136b78                                                   get
# https://mc.yandex.ru/metrika/watch.js                                                 get
#
#                                                                                            \
#                                                                                      freq
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 6
#
#                                                                                             \
#                                                                                      first
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://mc.yandex.ru/metrika/watch.js                                                 NaN
#
#                                                                                            \
#                                                                                      last
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://mc.yandex.ru/metrika/watch.js                                                 NaN
#
#                                                                                      symbol  \
#                                                                                       count
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 6
#
#                                                                                              \
#                                                                                      unique
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 1
#
#                                                                                                                                                      \
#                                                                                                                                                 top
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     window.navigator.mimeTypes[application/futuresplash].suffixes
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  window.navigator.mimeTypes[application/futuresplash].suffixes
# http://www.gap.com/akam/10/6e136b78                                                   window.navigator.mimeTypes[application/futuresplash].suffixes
# https://mc.yandex.ru/metrika/watch.js                                                 window.navigator.mimeTypes[application/futuresplash].suffixes
#
#                                                                                            \
#                                                                                      freq
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 6
#
#                                                                                             \
#                                                                                      first
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://mc.yandex.ru/metrika/watch.js                                                 NaN
#
#                                                                                            \
#                                                                                      last
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://mc.yandex.ru/metrika/watch.js                                                 NaN
#
#                                                                                      time_stamp  \
#                                                                                           count
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 6
#
#                                                                                              \
#                                                                                      unique
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 6
#
#                                                                                                                   \
#                                                                                                              top
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     2017-12-16 00:17:13.996000
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  2017-12-16 17:01:59.869000
# http://www.gap.com/akam/10/6e136b78                                                   2017-12-16 22:51:15.961000
# https://mc.yandex.ru/metrika/watch.js                                                 2017-12-16 05:29:38.177000
#
#                                                                                            \
#                                                                                      freq
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 1
#
#                                                                                                                   \
#                                                                                                            first
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     2017-12-16 00:17:13.996000
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  2017-12-16 17:01:59.869000
# http://www.gap.com/akam/10/6e136b78                                                   2017-12-16 22:51:15.961000
# https://mc.yandex.ru/metrika/watch.js                                                 2017-12-16 03:35:09.289000
#
#                                                                                                                   \
#                                                                                                             last
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     2017-12-16 00:17:13.996000
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  2017-12-16 17:01:59.869000
# http://www.gap.com/akam/10/6e136b78                                                   2017-12-16 22:51:15.961000
# https://mc.yandex.ru/metrika/watch.js                                                 2017-12-16 14:09:46.541000
#
#                                                                                      value_1000  \
#                                                                                           count
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 6
#
#                                                                                              \
#                                                                                      unique
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 1
#
#                                                                                            \
#                                                                                       top
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     spl
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  spl
# http://www.gap.com/akam/10/6e136b78                                                   spl
# https://mc.yandex.ru/metrika/watch.js                                                 spl
#
#                                                                                            \
#                                                                                      freq
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 6
#
#                                                                                             \
#                                                                                      first
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://mc.yandex.ru/metrika/watch.js                                                 NaN
#
#                                                                                            \
#                                                                                      last
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://mc.yandex.ru/metrika/watch.js                                                 NaN
#
#                                                                                      location_domain  \
#                                                                                                count
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 6
#
#                                                                                              \
#                                                                                      unique
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 3
#
#                                                                                                   \
#                                                                                              top
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     ufc.ca
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  lemonde.fr
# http://www.gap.com/akam/10/6e136b78                                                   gap.com
# https://mc.yandex.ru/metrika/watch.js                                                 vjav.com
#
#                                                                                            \
#                                                                                      freq
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 3
#
#                                                                                             \
#                                                                                      first
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://mc.yandex.ru/metrika/watch.js                                                 NaN
#
#                                                                                            \
#                                                                                      last
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://mc.yandex.ru/metrika/watch.js                                                 NaN
#
#                                                                                      script_domain  \
#                                                                                              count
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 6
#
#                                                                                              \
#                                                                                      unique
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 1
#
#                                                                                                       \
#                                                                                                  top
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     cloudfront.net
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  lemde.fr
# http://www.gap.com/akam/10/6e136b78                                                   gap.com
# https://mc.yandex.ru/metrika/watch.js                                                 yandex.ru
#
#                                                                                            \
#                                                                                      freq
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 6
#
#                                                                                             \
#                                                                                      first
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://mc.yandex.ru/metrika/watch.js                                                 NaN
#
#                                                                                            \
#                                                                                      last
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://mc.yandex.ru/metrika/watch.js                                                 NaN
#
#                                                                                      location_base_url  \
#                                                                                                  count
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 6
#
#                                                                                              \
#                                                                                      unique
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 3
#
#                                                                                                       \
#                                                                                                  top
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     www.ufc.ca
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  www.lemonde.fr
# http://www.gap.com/akam/10/6e136b78                                                   www.gap.com
# https://mc.yandex.ru/metrika/watch.js                                                 www.vjav.com
#
#                                                                                            \
#                                                                                      freq
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     1
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  1
# http://www.gap.com/akam/10/6e136b78                                                   1
# https://mc.yandex.ru/metrika/watch.js                                                 3
#
#                                                                                             \
#                                                                                      first
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://mc.yandex.ru/metrika/watch.js                                                 NaN
#
#
#                                                                                      last
# script_url
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js                                     NaN
# http://s1.lemde.fr/medias/web/e6a5b4d902b44812df0af2f4d94778d1/js/lib/fingerprint.js  NaN
# http://www.gap.com/akam/10/6e136b78                                                   NaN
# https://mc.yandex.ru/metrika/watch.js                                                 NaN

# %% [markdown]
# I did little internet search on `https://mc.yandex.ru/metrika/watch.js` and found this [script](https://github.com/ValdikSS/p0f-mtu-script/blob/master/index.php). Looking at the script I can see that it produces a hash and matches it with stored hashes to identify a client. The information used is fethed from `https://mc.yandex.ru/metrika/watch.js`. Therefore this can also potentially be used as fingerprinting script.

# %% [markdown]
# Finally `FuturesplashSuffixes` identifies 4 scripts all of which are tracking scripts. Therefore this is a very powerful feature and we can run this on a bigger dataset to find more scripts. This should also go in our heuristic to detect attempts at browser attribute fingerprinting.
#
# We are walking towards building a heuristic by collecting such example and therefore answering my Q3 using this analysis.
