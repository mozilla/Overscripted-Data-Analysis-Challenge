# %%
import json
import os
import pandas as pd
import requests
import ssl
import sys
import urllib
from configparser import ConfigParser
from slugify import slugify

# %%
# Specify inputs
parser = ConfigParser()
parser.read('config.ini')

# Program state: either looking for existing
USE_EXISTING_LOOKUP = False
if (parser['Downloading'] == "True"):
    USE_EXISTING_LOOKUP = True   

# Main working directory
MAIN_DIR = parser['Downloading']['ParentWorkingDirectory']

# Where the files will be downloaded to
DATA_DIR = MAIN_DIR + parser['Downloading']['JSOutputDirectory']

# If generating or looking up a table
LOOKUP_DIR = MAIN_DIR + parser['Downloading']['LookupDirectory']
LOOKUP_FILE = parser['Downloading']['LookupFile']

# If generating a new dataset
if (bool(parser['Downloading']['ParquetDataset'])):
    PARQUET_FILE = MAIN_DIR + parser['Downloading']['ParquetDataset']      # running over sample data

# %%
def shorten_name(url_name):
    shortened_url = url_name.replace('https://', '').replace('http://', '').replace('/', '_')
    shortened_url = slugify(shortened_url)[:250]
    suffix = '.txt'
    file_name = shortened_url + suffix
    
    return file_name

# %%
if (USE_EXISTING_LOOKUP & os.path.isfile(LOOKUP_DIR + LOOKUP_FILE)):
    print("Existing Lookup table found...")
    url_data = pd.read_csv(LOOKUP_DIR + LOOKUP_FILE)
    
else:
    print("Generating Lookup table...")
    raw_data = pd.read_parquet(PARQUET_FILE, engine='pyarrow')
    url_data = pd.DataFrame()
    url_data['url'] = raw_data['script_url'].unique()
    url_data['filename'] = url_data['url'].apply(shorten_name)
    url_data = url_data.sort_values('filename')
    url_data['status'] = -1
# Out:
# Generating Lookup table...

# %%
url_data
# Out:
#                                                    url  \
# 118                  http://a.visualrevenue.com/vrs.js
# 97   https://a1.alicdn.com/creation/html/2016/06/20...
# 426  https://acc.alicdn.com/tfscom/TB1XEs7RXXXXXXuX...
# 443  https://ad.doubleclick.net/ddm/adi/N46101.2990...
# 13   http://ads.pubmatic.com/AdServer/js/showad.js#...
# 72   https://ae.nflximg.net/containers/prod/300x250...
# 18   http://ajax.googleapis.com/ajax/libs/swfobject...
# 1    https://ajax.googleapis.com/ajax/libs/webfont/...
# 167  https://api.moxielinks.com/perform.php?action=...
# 27               https://apis.google.com/js/plusone.js
# 32   https://apis.google.com/_/scs/apps-static/_/js...
# 245  https://apis.google.com/_/scs/apps-static/_/js...
# 364  https://apis.google.com/_/scs/apps-static/_/js...
# 54   https://apis.google.com/_/scs/apps-static/_/js...
# 28   https://apis.google.com/_/scs/apps-static/_/js...
# 228  https://apis.google.com/_/scs/apps-static/_/js...
# 405  https://assets.adobedtm.com/b0e777405f8f7de62e...
# 400  https://assets.adobedtm.com/b0e777405f8f7de62e...
# 349  https://assets.adobedtm.com/c92c0145fffcd7754b...
# 353  https://assets.adobedtm.com/c92c0145fffcd7754b...
# 114  https://assets.adobedtm.com/fb2536241e31a607da...
# 108  https://assets.adobedtm.com/fb2536241e31a607da...
# 100  https://assets.shopfront.envato-static.com/v0-...
# 99   https://assets.shopfront.envato-static.com/ven...
# 89   http://atir.aipai.com/attachment/jslib/jquery-...
# 98   https://audiojungle.net/category/music-kits/pe...
# 417  http://b.fengyx.com/m.html?mediaid=ea0566d81d1...
# 21            http://b.scorecardresearch.com/beacon.js
# 83   https://b97.yahoo.co.jp/pagead/conversion_asyn...
# 248                http://baike.pcauto.com.cn/147.html
# ..                                                 ...
# 10   https://www.syracuse.edu/wp-content/themes/g6-...
# 11   https://www.syracuse.edu/wp-includes/js/wp-emb...
# 7    https://www.syracuse.edu/wp-includes/js/wp-emo...
# 324  https://www.tatasky.com/wps/contenthandler/!ut...
# 325  https://www.tatasky.com/wps/portal/TataSky/cha...
# 337             http://www.topky.sk/se/100334/Topky-TV
# 266  https://www.twilio.com/docs/static/js/docs.min...
# 264  https://www.twilio.com/docs/static/js/vendor.m...
# 130  https://www.urcosme.com/assets/application-989...
# 46   https://www.vjav.com/assets/bundle.916fc0a42c6...
# 41   https://www.vjav.com/assets/vendor.916fc0a42c6...
# 71                 http://www.wits.ac.za/givingtowits/
# 70   http://www.wits.ac.za/media/wits-university-st...
# 151  https://www.youtube.com/yts/jsbin/desktop_poly...
# 53   https://www.youtube.com/yts/jsbin/player-vflyo...
# 149  https://www.youtube.com/yts/jsbin/spf-vflRfjT3...
# 150  https://www.youtube.com/yts/jsbin/webcomponent...
# 52   https://www.youtube.com/yts/jsbin/www-embed-pl...
# 255  http://www1.pcauto.com.cn/common/js/pcauto.log...
# 373  https://yj-a.p.adnxs.com/ttj?id=12302129&posit...
# 445  https://z.moatads.com/groupmvolvo744979952275/...
# 79   https://z.moatads.com/iprospectusadidasdcm9492...
# 14   https://z.moatads.com/keplerpaypaldcm168224283...
# 219  https://z.moatads.com/keplerpaypaldcm168224283...
# 260  https://z.moatads.com/quantcastv2691176990399/...
# 438  https://z.moatads.com/universalorlandodcm47688...
# 360  https://zn5bcphyj6qs0s0o9-backcountrycom.sitei...
# 467  https://zona.mobi/build/2.bundle-508a1ea127180...
# 468  https://zona.mobi/build/3.bundle-508a1ea127180...
# 465               https://zona.mobi/movies/gadkii-ya-3
#
#                                               filename  status
# 118                     a-visualrevenue-com-vrs-js.txt      -1
# 97   a1-alicdn-com-creation-html-2016-06-20-creatio...      -1
# 426  acc-alicdn-com-tfscom-tb1xes7rxxxxxxuxxxxxxxxx...      -1
# 443  ad-doubleclick-net-ddm-adi-n46101-2990edmunds-...      -1
# 13   ads-pubmatic-com-adserver-js-showad-js-pix-kdn...      -1
# 72   ae-nflximg-net-containers-prod-300x250-monet-m...      -1
# 18   ajax-googleapis-com-ajax-libs-swfobject-2-2-sw...      -1
# 1    ajax-googleapis-com-ajax-libs-webfont-1-6-26-w...      -1
# 167  api-moxielinks-com-perform-php-action-category...      -1
# 27                   apis-google-com-js-plusone-js.txt      -1
# 32   apis-google-com-scs-apps-static-js-k-oz-gapi-e...      -1
# 245  apis-google-com-scs-apps-static-js-k-oz-gapi-e...      -1
# 364  apis-google-com-scs-apps-static-js-k-oz-gapi-e...      -1
# 54   apis-google-com-scs-apps-static-js-k-oz-gapi-e...      -1
# 28   apis-google-com-scs-apps-static-js-k-oz-gapi-e...      -1
# 228  apis-google-com-scs-apps-static-js-k-oz-gapi-e...      -1
# 405  assets-adobedtm-com-b0e777405f8f7de62ef5644657...      -1
# 400  assets-adobedtm-com-b0e777405f8f7de62ef5644657...      -1
# 349  assets-adobedtm-com-c92c0145fffcd7754b23c04a80...      -1
# 353  assets-adobedtm-com-c92c0145fffcd7754b23c04a80...      -1
# 114  assets-adobedtm-com-fb2536241e31a607daba5441f4...      -1
# 108  assets-adobedtm-com-fb2536241e31a607daba5441f4...      -1
# 100  assets-shopfront-envato-static-com-v0-99a91edf...      -1
# 99   assets-shopfront-envato-static-com-vendor-4635...      -1
# 89   atir-aipai-com-attachment-jslib-jquery-1-8-3-m...      -1
# 98   audiojungle-net-category-music-kits-percussion...      -1
# 417  b-fengyx-com-m-html-mediaid-ea0566d81d18d1aad6...      -1
# 21               b-scorecardresearch-com-beacon-js.txt      -1
# 83      b97-yahoo-co-jp-pagead-conversion-async-js.txt      -1
# 248                   baike-pcauto-com-cn-147-html.txt      -1
# ..                                                 ...     ...
# 10   www-syracuse-edu-wp-content-themes-g6-carbon-j...      -1
# 11   www-syracuse-edu-wp-includes-js-wp-embed-min-j...      -1
# 7    www-syracuse-edu-wp-includes-js-wp-emoji-relea...      -1
# 324  www-tatasky-com-wps-contenthandler-ut-p-digest...      -1
# 325  www-tatasky-com-wps-portal-tatasky-channels-hi...      -1
# 337                www-topky-sk-se-100334-topky-tv.txt      -1
# 266  www-twilio-com-docs-static-js-docs-min-967-js.txt      -1
# 264  www-twilio-com-docs-static-js-vendor-min-967-j...      -1
# 130  www-urcosme-com-assets-application-989a9633c70...      -1
# 46   www-vjav-com-assets-bundle-916fc0a42c6d2453bb3...      -1
# 41   www-vjav-com-assets-vendor-916fc0a42c6d2453bb3...      -1
# 71                     www-wits-ac-za-givingtowits.txt      -1
# 70   www-wits-ac-za-media-wits-university-style-ass...      -1
# 151  www-youtube-com-yts-jsbin-desktop-polymer-vflu...      -1
# 53   www-youtube-com-yts-jsbin-player-vflyogrhd-en-...      -1
# 149  www-youtube-com-yts-jsbin-spf-vflrfjt3b-spf-js...      -1
# 150  www-youtube-com-yts-jsbin-webcomponents-lite-m...      -1
# 52   www-youtube-com-yts-jsbin-www-embed-player-vfl...      -1
# 255  www1-pcauto-com-cn-common-js-pcauto-login-1-7-...      -1
# 373  yj-a-p-adnxs-com-ttj-id-12302129-position-abov...      -1
# 445  z-moatads-com-groupmvolvo744979952275-moatad-j...      -1
# 79   z-moatads-com-iprospectusadidasdcm949238145220...      -1
# 14   z-moatads-com-keplerpaypaldcm168224283233-moat...      -1
# 219  z-moatads-com-keplerpaypaldcm168224283233-moat...      -1
# 260  z-moatads-com-quantcastv2691176990399-moatad-j...      -1
# 438  z-moatads-com-universalorlandodcm476885909785-...      -1
# 360  zn5bcphyj6qs0s0o9-backcountrycom-siteintercept...      -1
# 467  zona-mobi-build-2-bundle-508a1ea12718028bdec3-...      -1
# 468  zona-mobi-build-3-bundle-508a1ea12718028bdec3-...      -1
# 465                   zona-mobi-movies-gadkii-ya-3.txt      -1
#
# [470 rows x 3 columns]

# %%
#for url_name in df['script_url'].unique():
#    file_name = shorten_name(DATA_DIR, url_name)
#    
#    #with open(file_name, 'w') as source_file:

#    try:
#        r = requests.get(url_name, verify=False)
#        print("{}\n\t\t{}".format(url_name, r.status_code))
#    except (requests.exceptions.RequestException) as e:
#        print("{}\n\t\t{}".format(url_name, e))

# %%
ssl._create_default_https_context = ssl._create_unverified_context
failed = []

for url_name in url_data['script_url']:
    
    
    with open(file_name, 'w') as source_file:
        try:
            source_file.write(urllib.request.urlopen(url_name).read().decode(
                'utf-8', 'backslashreplace'))
            print(url_name)
            print("")

        except (urllib.error.URLError, ValueError) as e:
            failed.append(url_name)
            print('Attempted:', url_name)
            print(str(e), '\n')
# Out:
# https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
#
# https://ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js
#
# http://cpro.baidustatic.com/cpro/ui/noexpire/js/4.0.1/adClosefeedbackUpgrade.min.js
#
# https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=fe1ad16a94c816&origin=http%3A%2F%2Farabi21.com
#
# https://static.dynamicyield.com/scripts/12290/dy-coll-min.js
#
# https://www.syracuse.edu/about/
#
# https://www.googletagmanager.com/gtm.js?id=GTM-5FC97GL
#
# https://www.syracuse.edu/wp-includes/js/wp-emoji-release.min.js?ver=4.9.1
#
# https://www.google-analytics.com/analytics.js
#
# https://code.jquery.com/jquery-migrate-1.4.1.min.js
#
# https://www.syracuse.edu/wp-content/themes/g6-carbon/js/carbon-all.js?ver=6.3.6
#
# https://www.syracuse.edu/wp-includes/js/wp-embed.min.js?ver=4.9.1
#
# https://syr-piwik-prod.syr.edu/piwik.js
#
# http://ads.pubmatic.com/AdServer/js/showad.js#PIX&kdntuid=1&SPug=true&p=37855&predirect=http%3A%2F%2Fdelivery.swid.switchadhub.com%2Fadserver%2Fuser_sync.php%3FSWID%3Dc3a5b350611a2a8227e5f3e7fb4785fc%26sKey%3DPM3%26sVal%3D%26do%5Bsingle%5D%3D1&it=0&np=0
#
# https://z.moatads.com/keplerpaypaldcm168224283233/moatad.js#moatClientLevel1=11459972&moatClientLevel2=3346219&moatClientLevel3=210658248&moatClientLevel4=95946136&zMoatG=ct=US&st=&city=0&dma=0&zp=&bw=4&zMoatUSER=AMsySZYB24A5c8yM4Xpv9GSzr-9f
#
# https://securepubads.g.doubleclick.net/gpt/pubads_impl_170.js
#
# http://cdn.optimizely.com/js/549871026.js
#
# http://w.sharethis.com/button/sharethis.js#&offsetLeft=-283&offsetTop=-7&publisher=8a80909b-bbba-4773-ad9c-57ff5f2349d5&type=website&post_services=email%2Cfacebook%2Ctwitter%2Cgbuzz%2Cmyspace%2Cdigg%2Csms%2Cwindows_live%2Cdelicious%2Cstumbleupon%2Creddit%2Cgoogle_bmarks%2Clinkedin%2Cbebo%2Cybuzz%2Cblogger%2Cyahoo_bmarks%2Cmixx%2Ctechnorati%2Cfriendfeed%2Cpropeller%2Cwordpress%2Cnewsvine&button=false
#
# http://ajax.googleapis.com/ajax/libs/swfobject/2.2/swfobject.js
#
# http://www.google-analytics.com/analytics.js
#
# http://cdn.mplxtms.com/s/MasterTMS.min.js#2076
#
# http://b.scorecardresearch.com/beacon.js
#
# https://www.googletagmanager.com/gtm.js?id=GTM-WZQCWK
#
# http://dthq3mor50viz.cloudfront.net/zbajck9faU.js
#
# http://pagead2.googlesyndication.com/pagead/osd.js
#
# http://media.ufc.tv/ufc_system_assets/ufc_201707101050/js/jwplayer7/jwplayer.js
#
# http://media.ufc.tv/ufc_system_assets/ufc_201707101050/js/cufon-yui.js
#
# https://apis.google.com/js/plusone.js
#
# Attempted: https://apis.google.com/_/scs/apps-static/_/js/k=oz.gapi.en_US.u6kjN8qjK4c.O/m=plusone/rt=j/sv=1/d=1/ed=1/am=AQ/rs=AGLTcCNyWKI1jWTPxsTegkpGnwIGUlr0VQ/cb=gapi.loaded_0
# HTTP Error 404: Not Found
#
# https://platform.twitter.com/widgets.js
#
# http://ssl.p.jwpcdn.com/player/v/7.7.4/sharing.js
#
# http://ssl.p.jwpcdn.com/player/v/7.7.4/jwpsrv.js
#
# Attempted: https://apis.google.com/_/scs/apps-static/_/js/k=oz.gapi.en_US.u6kjN8qjK4c.O/m=auth/exm=plusone/rt=j/sv=1/d=1/ed=1/am=AQ/rs=AGLTcCNyWKI1jWTPxsTegkpGnwIGUlr0VQ/cb=gapi.loaded_1
# HTTP Error 404: Not Found
#
# http://connect.facebook.net/en_US/sdk.js
#
# http://imasdk.googleapis.com/js/sdkloader/ima3.js
#
# https://s0.2mdn.net/instream/video/client.js
#
# https://www.google.com/uds/api/search/1.0/298d032c4894311057ee9acd81a781f2/default+en.I.js
#
# http://static.chartbeat.com/js/chartbeat_video.js
#
# https://s.yimg.jp/images/advertising/common/js/iicon.min.js?2017121601
#
# https://platform.twitter.com/widgets/tweet_button.64457a6e8f493e1f1022f50e4e7e67e8.ja.html#dnt=false&id=twitter-widget-0&lang=ja&original_referer=https%3A%2F%2Fwww.waseda.jp%2Ftop%2Fnews%2F54733&size=m&text=%E8%8B%B1%E5%9B%BD%E3%81%AB%E3%81%A6%E9%96%8B%E5%82%AC%E3%80%8C%E8%9C%B7%E5%B7%9D%E3%82%B7%E3%82%A7%E3%82%A4%E3%82%AF%E3%82%B9%E3%83%94%E3%82%A2%E3%82%92%E3%82%81%E3%81%90%E3%81%A3%E3%81%A6%E3%80%8D%E3%80%80%E6%97%A9%E7%A8%B2%E7%94%B0%E5%A4%A7%E5%AD%A6%C3%97%E3%83%90%E3%83%BC%E3%83%9F%E3%83%B3%E3%82%AC%E3%83%A0%E5%A4%A7%E5%AD%A6%20%E2%80%93%20%E6%97%A9%E7%A8%B2%E7%94%B0%E5%A4%A7%E5%AD%A6&time=1513459096818&type=share&url=http%3A%2F%2Fwww.waseda.jp%2Ftop%2Fnews%2F54733
#
# https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f1bcb6bfb9c21f2&origin=http%3A%2F%2Fwww.rfa.org
#
# Attempted: https://www.vjav.com/assets/vendor.916fc0a42c6d2453bb38.min.js
# HTTP Error 403: Forbidden
#
# Attempted: https://script.bangdom.com/err/nino_adv.js?v=1510569849631
# HTTP Error 403: Forbidden
#
# https://www.googletagmanager.com/gtm.js?id=GTM-MW9PQ3
#
# https://d31qbv1cthcecs.cloudfront.net/atrk.js
#
# https://www.ps7894.com/InterYield/bindevent.do?e=click&affiliate=tubecorp&subid=6F&maxAdCountsPerInterval=0&aeplus=true&ae=true&aecount=1&aedelay1=15&aedelay2=30&aedelay3=45&aedelay4=60&aesnooze=100&snoozeMinutes=1&adCountIntervalHours=24&pop=under&attributionDisabled=true&endpoint=https%3A%2F%2Fwww.ps7894.com&thirdpartyrd=http%3A%2F%2Fisecurepay.com%2Fin%2Ftd583%2F%3Furl%3D%3C%3CURL%3E%3E%26sub%3D0
#
# Attempted: https://www.vjav.com/assets/bundle.916fc0a42c6d2453bb38.min.js
# HTTP Error 403: Forbidden
#
# https://www.ps7894.com/p1.0-SNAPSHOT.142%2C984.do&a=true&e=click&ab=false
#
# https://mc.yandex.ru/metrika/watch.js
#
# https://hm.baidu.com/hm.js?2337f2e83d566c915b997eefb8fad98e
#
# https://www.googletagmanager.com/gtm.js?id=GTM-M66T72
#
# https://www.google-analytics.com/gtm/js?id=GTM-KX39WKQ&t=gtm3&cid=562489143.1513412596
#
# https://www.youtube.com/yts/jsbin/www-embed-player-vflml4-Bf/www-embed-player.js
#
# https://www.youtube.com/yts/jsbin/player-vflyoGrhd/en_US/base.js
#
# Attempted: https://apis.google.com/_/scs/apps-static/_/js/k=oz.gapi.en_US.u6kjN8qjK4c.O/m=googleapis_client,gapi_iframes_style_common,gapi_iframes_iframer/am=AQ/rt=j/d=1/rs=AGLTcCNyWKI1jWTPxsTegkpGnwIGUlr0VQ
# HTTP Error 404: Not Found
#
# https://cdn.onthe.io/io.js/VXU0YbpZaW2C
#
# https://s.ytimg.com/yts/jsbin/www-widgetapi-vflgi1B_c/www-widgetapi.js
#
# https://scdn.cxense.com/cx.js
#
# https://www.1111.com.tw/includesU/jquery-1.4.3.min.js
#
# https://www.googleadservices.com/pagead/conversion.js
#
# https://bat.bing.com/bat.js
#
# https://d31j93rd8oukbv.cloudfront.net/metrika/watch_ua.js
#
# https://pagead2.googlesyndication.com/pagead/js/r20171206/r20110914/abg.js
#
# https://tpc.googlesyndication.com/sodar/Yww8ZxGu.js
#
# https://pagead2.googlesyndication.com/pagead/js/lidar.js
#
# https://tpc.googlesyndication.com/pagead/js/r20171206/r20110914/activeview/osd_listener.js
#
# Attempted: https://www.gstatic.com/recaptcha/api2/r20171212152908/recaptcha__en.js
# HTTP Error 404: Not Found
#
# https://cpro.baidustatic.com/cpro/ui/noexpire/js/4.0.0/adClosefeedbackUpgrade.min.js
#
# http://s1.mediaad.org/serve/akairan.com/loader.js
#
# http://www.akairan.com/koodak/templates/theme2/js/jquery-2.1.3.min.js
#
# http://www.wits.ac.za/media/wits-university-style-assets/javascript/slick.min.js
#
# http://www.wits.ac.za/givingtowits/
#
# https://ae.nflximg.net/containers/prod/300x250_monet_monet.zip_83cf3429-06e7-4a9e-88e5-71626d73c01d/1.4/js/Temple.js
#
# https://pagead2.googlesyndication.com/pagead/js/r20171206/r20170110/show_ads_impl.js
#
# Attempted: http://script.bangdom.com/pjs/2.6.8.js?_=1513450078120
# HTTP Error 403: Forbidden
#
# https://socauth.privatbank.ua/cp/handler.html?startLoadFrame=1513446200677&quick_start=1&is_collect_gpu=1&seance=1513446200681.4720.11298200094359412allo.ua0.28448962083973395&visit_num=1&sys=10012355.UA&redirect_count=0&navigation_type=0&navigation_start_datetime=1513446192&visit_id=1513446200683.01270.8876955822750051https%253A%252F%252Fallo.ua%252Fser-gi-zolotye%252F0.5739396161305099&load_time=6
#
# Attempted: /_/scs/shopping-verified-reviews-static/_/js/k=boq-shopping-verified-reviews.VerifiedReviewsGcrProxyUi.en_US.DwoKXA2JTCM.O/ck=boq-shopping-verified-reviews.VerifiedReviewsGcrProxyUi.14ay2tvzlwwh7.L.F4.O/m=syg,OJUrvb,syf,syi,_latency,FCpbqb,WhJNk/rt=j/d=0/excm=emptyview,_b,_tp/ed=1/rs=AC8lLkQC8gLvGkNHSRDrUqsSzT7G6sVjMw
# unknown url type: '/_/scs/shopping-verified-reviews-static/_/js/k=boq-shopping-verified-reviews.VerifiedReviewsGcrProxyUi.en_US.DwoKXA2JTCM.O/ck=boq-shopping-verified-reviews.VerifiedReviewsGcrProxyUi.14ay2tvzlwwh7.L.F4.O/m=syg,OJUrvb,syf,syi,_latency,FCpbqb,WhJNk/rt=j/d=0/excm=emptyview,_b,_tp/ed=1/rs=AC8lLkQC8gLvGkNHSRDrUqsSzT7G6sVjMw'
#
# https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-1965383259143495&output=html&h=600&slotname=9702403710&adk=3889590138&adf=843632250&w=300&lmt=1513465217&loeid=38893312&format=300x600&url=http%3A%2F%2Ffootball.ua%2Fclub%2F53-athletic.html&flash=28.0.0&wgl=1&adsid=NT&dt=1513465213086&bpp=8&bdt=7813&fdt=4017&idt=4723&shv=r20171206&cbv=r20170110&saldr=aa&prev_fmts=728x90&correlator=5048184556052&frm=20&ga_vid=1903957605.1513465208&ga_sid=1513465209&ga_hid=656656055&ga_fc=1&pv=1&icsg=2&nhd=1&dssz=2&mdo=0&mso=0&u_tz=0&u_his=1&u_java=0&u_h=768&u_w=1366&u_ah=768&u_aw=1366&u_cd=24&u_nplug=1&u_nmime=2&adx=907&ady=205&biw=1353&bih=697&abxe=1&eid=21061122%2C38893302%2C191880502&oid=3&nmo=1&rx=0&eae=0&fc=528&brdim=%2C%2C0%2C0%2C1366%2C0%2C1366%2C768%2C1366%2C697&vis=1&rsz=%7C%7CeoE%7C&abl=CS&ppjl=f&pfx=0&fu=16&bc=1&ifi=2&xpc=auq0eV4EE2&p=http%3A//football.ua&dtd=4788
#
# https://s0.2mdn.net/879366/express_html_inpage_rendering_lib_200_216.js
#
# https://z.moatads.com/iprospectusadidasdcm949238145220/moatad.js#moatClientLevel1=20560416&moatClientLevel2=2445008&moatClientLevel3=210642386&moatClientLevel4=95827831&zMoatG=ct=US&st=&city=0&dma=0&zp=&bw=4&zMoatADV=5094938&zMoatUSER=0
# https://cdn.krxd.net/controltag/rkrioms3o.js?advertiserid=5094938;campaignid=20560416;adid=410398615;siteid=2445008;placementid=210642386;creativeid=95827831
#
# https://cdn.krxd.net/ctjs/controltag.js.c3e8e6311e44dfc4f051e4a261784fa1
#
# https://c.iogous.com/js/banner/DIGITALICE_REC.js
#
# https://b97.yahoo.co.jp/pagead/conversion_async.js
#
# https://rsv.dga.jp/s/click_sec/new_i_search_assist.js
#
# http://wfpscripts.webspectator.com/adblocker/blockadblock.js
#
# https://cpro.baidustatic.com/sync.htm?cproid=0FF010C18A9DD8D15614FA2FE581A5F3%3AFG%3D1
#
# https://static.criteo.net/js/ld/ld.js
#
# https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f115af0c85ff058&origin=https%3A%2F%2Ffishki.net
#
# http://atir.aipai.com/attachment/jslib/jquery-1.8.3.min.js
#
# http://mlog.aipai.com/apweb.min.js
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-88c8a76440b0> in <module>()
#      16     with open(file_name, 'w') as source_file:
#      17         try:
# ---> 18             source_file.write(urllib.request.urlopen(url_name).read().decode(
#      19                 'utf-8', 'backslashreplace'))
#      20             print(url_name)
#
# /usr/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /usr/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# /usr/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# /usr/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /usr/lib/python3.6/urllib/request.py in http_open(self, req)
#    1344
#    1345     def http_open(self, req):
# -> 1346         return self.do_open(http.client.HTTPConnection, req)
#    1347
#    1348     http_request = AbstractHTTPHandler.do_request_
#
# /usr/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
# -> 1321             r = h.getresponse()
#    1322         except:
#    1323             h.close()
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
from pathlib import Path
PARQUET_DIR = Path('/mnt/Data/UCOSP_DATA/resources/trial_1_fulldata/')
full_df = pd.concat(
    pd.read_parquet(parquet_file)
    for parquet_file in PARQUET_DIR.glob('*.parquet')
)

# %%
from pyspark.sql import SparkSession, functions, types
spark = SparkSession.builder.appName('URL getter').getOrCreate()
data = spark.read.parquet('/mnt/Data/UCOSP_DATA/resources/full_url_list_v2/*')
#data = spark.read.parquet('/mnt/Data/UCOSP_DATA/resources/sample_full_url_list/*')

# %%
data.count()
# Out:
# 1253168
